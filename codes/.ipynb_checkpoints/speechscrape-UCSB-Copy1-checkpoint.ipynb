# %% [markdown]
# ## Import libraries

# %%
import json
import requests
from bs4 import BeautifulSoup
import re
import os
import time
import csv
from collections import defaultdict
from datetime import date

# %% [markdown]
# ## Define search parameters

# %%
# base URL for scrapping
root = 'https://www.presidency.ucsb.edu'

# search based on name, title, and date
# date is between 1) receives party nomination and 2) election day 
cand_dict = {1: {'first': 'George-w', 'last': 'Bush', 'title': 'President', 'start': date(2000, 8, 3), 'end': date(2000, 12, 12)},#2000
             2: {'first': 'Albert', 'last': 'Gore-jr', 'title': 'VP', 'start': date(2000, 8, 17), 'end': date(2000, 12, 12)},
             3: {'first': 'George-w', 'last': 'Bush', 'title': 'President', 'start': date(2004, 9, 2), 'end': date(2004, 11, 2)}, #2004
             4: {'first': 'John-f', 'last': 'Kerry', 'title': 'Senator', 'start': date(2004, 7, 29), 'end': date(2004, 11, 2)},
             5: {'first': 'Barack', 'last': 'Obama', 'title': 'President', 'start': date(2008, 8, 28), 'end': date(2008, 11, 3)},#2008
             6: {'first': 'John', 'last': 'McCain', 'title': 'Senator', 'start': date(2008, 9, 4), 'end': date(2008, 11, 3)}, 
             7: {'first': 'Barack', 'last': 'Obama', 'title': 'President', 'start': date(2012, 9, 6), 'end': date(2012, 11, 6)},#2012
             8: {'first': 'Mitt', 'last': 'Romney', 'title': 'Governor', 'start': date(2012, 8, 30), 'end': date(2012, 11, 6)},
             9: {'first': 'Donald-j', 'last': 'Trump', 'title': 'President', 'start': date(2016, 7, 21), 'end': date(2016, 11, 8)}, #2016
             10: {'first': 'Hillary', 'last': 'Clinton', 'title': 'Secretary', 'start': date(2016, 7, 28), 'end': date(2016, 11, 8)}}

# %% [markdown]
# ## Scrape, write txt and meta data

# %%
for cand in range(1,11):  
    #create candidate specific url string
    if cand_dict[cand]['title'] == "President":
        candidate = '/people/president/' + cand_dict[cand]['first'] + '-' + cand_dict[cand]['last'] + '?page=' 
    else:
        candidate = '/people/other/' + cand_dict[cand]['first'] + '-' + cand_dict[cand]['last'] + '?page=' 
    candidate_iter = 0

    speech_path = 'speeches_' + cand_dict[cand]['last'].lower() + '_ucsb'
    try:  
        os.mkdir(speech_path)
    except OSError:
        pass
    # first go into candidate page
    r = requests.get(root + candidate.lower() + str(candidate_iter))
    soup = BeautifulSoup(r.text, 'html.parser')
    # locate the final page
    try: 
        fin = soup.find_all('a', title = 'Go to last page')
     # find max page number
        max_p = int(re.findall(r'page=([0-9]+)', str(fin[0]))[0])
    except: 
        max_p = 1


    # initialize metadata dict
    metadata = defaultdict(list)

    for iter in range(candidate_iter, max_p + 1):

        r = requests.get(root + candidate.lower() + str(iter))
        soup = BeautifulSoup(r.text, 'html.parser')
        titles_raw = soup.findAll(class_="views-field views-field-title")
        dates_raw = soup.findAll(class_="date-display-single")

        
        links = []
        for x in titles_raw:
            links.append(x.a['href'])
        titles = []
        for x in titles_raw:
            titles.append(x.a.contents[0])
        dates = []
        for x in dates_raw: 
            date_raw = re.findall(r'content="([0-9]{4})-([0-9]{2})-([0-9]{2})', str(x))
#             print(int(date_raw[0][2]))
            if int(date_raw[0][0]) < 1980:
                continue
            speechdate = date(int(date_raw[0][0]), int(date_raw[0][1]), int(date_raw[0][2]))
            dates.append(speechdate)

        assert len(links) == len(titles) == len(dates)

        lengthbefore = len(metadata)

        for i in range(len(metadata), len(metadata) + len(links)):
            metadata[i] = [links[i - lengthbefore], titles[i - lengthbefore], dates[i - lengthbefore]]
            
    ### save all speeches in csv files
#     with open('metadata_all' + str(cand_dict[cand]['last']) + str(cand_dict[cand]['start'])[2:4] + '.csv', 'w') as csvfile:  
#     # creating a csv writer object  
#         csvwriter = csv.writer(csvfile)     
#     # writing the data rows  
#         csvwriter.writerows(metadata.values()) 

### start extracting speeches that fit our parameters
    speechnum = 0

    meta = [] # also save meta of those speeches separately 
    for i in range(0, len(metadata)):
        # only keep within the pre-specified dates, and only if it comes with "remarks"
        if metadata[i][2] >= cand_dict[cand]['start'] and metadata[i][2] <= cand_dict[cand]['end'] and ("remarks" in metadata[i][1].lower() or ("address" in metadata[i][1].lower() and "nomination" in metadata[i][1].lower())): 
            speechnum += 1
            r = requests.get(root + metadata[i][0])
            soup = BeautifulSoup(r.text, 'html.parser')
            text_full = soup.findAll(class_='field-docs-content')[0].get_text()
            text = text_full
            try:
                location = soup.findAll(class_="field-spot-state")[0].get_text()
                metadata[i].append(location)
            except:
                continue
            try:
                filename = cand_dict[cand]['last'].lower() + '-speech-' + str(metadata[i][2]) + '-' + re.findall('[\w]+-[\w]+-[\w]+$', metadata[i][0])[0]
                print(filename)
            except:  
                continue
            with open(os.getcwd() + '/' + speech_path + '/' + filename + '.txt', 'w') as text_file:
                text_file.write(text)
            meta.append(metadata[i])

            
        
    with open("META" + str(cand_dict[cand]['last']) + str(cand_dict[cand]['start'])[2:4] + '.csv', 'w') as csvfile:
        csvwriter = csv.writer(csvfile)   
        #write header
        #csvwriter.wrtie
    # writing the data rows  
        csvwriter.writerows(meta)
# Out:
# bush-speech-2000-08-03-national-convention-0
# gore-jr-speech-2000-08-17-national-convention-los
# gore-jr-speech-2000-09-29-chevy-chase-maryland
# gore-jr-speech-2000-10-30-remarks-muskegon-michigan
# gore-jr-speech-2000-11-01-remarks-kissimmee-florida
# bush-speech-2004-09-02-convention-new-york
# bush-speech-2004-09-03-west-allis-wisconsin
# bush-speech-2004-09-03-remarks-moosic-pennsylvania
# bush-speech-2004-09-03-rapids-iowa-1
# bush-speech-2004-09-04-broadview-heights-ohio
# bush-speech-2004-09-04-remarks-erie-pennsylvania
# bush-speech-2004-09-04-remarks-kirtland-ohio
# bush-speech-2004-09-05-parkersburg-west-virginia
# bush-speech-2004-09-06-poplar-bluff-missouri
# bush-speech-2004-09-07-remarks-columbia-missouri
# bush-speech-2004-09-07-discussion-sedalia-missouri
# bush-speech-2004-09-07-lees-summit-missouri
# bush-speech-2004-09-08-remarks-intelligence-reform
# bush-speech-2004-09-08-center-miami-florida
# bush-speech-2004-09-09-remarks-johnstown-pennsylvania
# bush-speech-2004-09-09-remarks-colmar-pennsylvania
# bush-speech-2004-09-10-west-virginia-1
# bush-speech-2004-09-10-discussion-portsmouth-ohio
# bush-speech-2004-09-10-remarks-ironton-ohio
# bush-speech-2004-09-10-chillicothe-ohio-0
# bush-speech-2004-09-12-terrorist-attacks-russia
# bush-speech-2004-09-13-care-muskegon-michigan
# bush-speech-2004-09-13-creek-michigan-0
# bush-speech-2004-09-13-remarks-holland-michigan
# bush-speech-2004-09-14-states-las-vegas
# bush-speech-2004-09-14-greenwood-village-colorado
# bush-speech-2004-09-15-heritage-month-reception
# bush-speech-2004-09-16-rochester-minnesota-1
# bush-speech-2004-09-16-st-cloud-minnesota
# bush-speech-2004-09-16-care-blaine-minnesota
# bush-speech-2004-09-17-victory-2004-reception
# bush-speech-2004-09-17-charlotte-north-carolina
# bush-speech-2004-09-19-orange-beach-alabama
# bush-speech-2004-09-20-new-york-city
# bush-speech-2004-09-20-derry-new-hampshire
# bush-speech-2004-09-21-new-york-city
# bush-speech-2004-09-21-new-york-city
# bush-speech-2004-09-21-and-exchange-with
# bush-speech-2004-09-21-york-city-2
# bush-speech-2004-09-21-york-city-2
# bush-speech-2004-09-22-efforts-millvale-pennsylvania
# bush-speech-2004-09-22-remarks-latrobe-pennsylvania
# bush-speech-2004-09-22-king-prussia-pennsylvania
# bush-speech-2004-09-23-the-american-indian
# bush-speech-2004-09-23-bangor-maine-1
# bush-speech-2004-09-23-iraq-from-bangor
# bush-speech-2004-09-24-for-beslan-russia
# bush-speech-2004-09-24-education-janesville-wisconsin
# bush-speech-2004-09-24-remarks-racine-wisconsin
# bush-speech-2004-09-27-remarks-xenia-ohio
# bush-speech-2004-09-27-education-springfield-ohio
# bush-speech-2004-09-27-west-chester-ohio
# bush-speech-2004-09-29-lake-wales-florida
# bush-speech-2004-09-30-volunteers-stuart-florida
# bush-speech-2004-09-30-coral-gables-florida
# bush-speech-2004-10-01-new-hampshire-3
# bush-speech-2004-10-01-remarks-allentown-pennsylvania
# bush-speech-2004-10-02-cuyahoga-falls-ohio
# bush-speech-2004-10-02-builders-columbus-ohio
# bush-speech-2004-10-02-discussion-mansfield-ohio
# bush-speech-2004-10-04-discussion-clive-iowa
# bush-speech-2004-10-04-des-moines-iowa
# bush-speech-2004-10-06-barre-pennsylvania-0
# bush-speech-2004-10-06-farmington-hills-michigan
# bush-speech-2004-10-07-remarks-wausau-wisconsin
# bush-speech-2004-10-07-weapons-mass-destruction
# bush-speech-2004-10-08-party-ballwin-missouri
# bush-speech-2004-10-09-remarks-chanhassen-minnesota
# bush-speech-2004-10-09-st-louis-missouri
# bush-speech-2004-10-09-remarks-waterloo-iowa
# bush-speech-2004-10-11-remarks-morrison-colorado
# bush-speech-2004-10-11-hobbs-new-mexico
# bush-speech-2004-10-11-coors-denver-colorado
# bush-speech-2004-10-12-paradise-valley-arizona
# bush-speech-2004-10-12-colorado-springs-colorado
# bush-speech-2004-10-13-party-phoenix-arizona
# bush-speech-2004-10-14-reno-nevada-0
# bush-speech-2004-10-14-point-oregon-0
# bush-speech-2004-10-14-vegas-nevada-1
# bush-speech-2004-10-15-rapids-iowa-2
# bush-speech-2004-10-15-remarks-oshkosh-wisconsin
# bush-speech-2004-10-16-beach-florida-0
# bush-speech-2004-10-16-beach-florida-2
# bush-speech-2004-10-16-sunrise-florida-0
# bush-speech-2004-10-18-and-paralympic-teams
# bush-speech-2004-10-18-marlton-new-jersey
# bush-speech-2004-10-19-petersburg-florida-0
# bush-speech-2004-10-19-the-villages-florida
# bush-speech-2004-10-19-port-richey-florida
# bush-speech-2004-10-20-discussion-rochester-minnesota
# bush-speech-2004-10-20-mason-city-iowa
# bush-speech-2004-10-20-eau-claire-wisconsin
# bush-speech-2004-10-21-hershey-pennsylvania-0
# bush-speech-2004-10-21-downingtown-pennsylvania-0
# bush-speech-2004-10-22-discussion-canton-ohio
# bush-speech-2004-10-22-wilkes-barre-pennsylvania
# bush-speech-2004-10-23-remarks-melbourne-florida
# bush-speech-2004-10-23-remarks-lakeland-florida
# bush-speech-2004-10-23-remarks-jacksonville-florida
# bush-speech-2004-10-23-fort-myers-florida
# bush-speech-2004-10-24-alamogordo-new-mexico
# bush-speech-2004-10-25-council-bluffs-iowa
# bush-speech-2004-10-25-remarks-davenport-iowa
# bush-speech-2004-10-25-remarks-greeley-colorado
# bush-speech-2004-10-26-dubuque-iowa-0
# bush-speech-2004-10-26-remarks-onalaska-wisconsin
# bush-speech-2004-10-26-cuba-city-wisconsin
# bush-speech-2004-10-26-richland-center-wisconsin
# bush-speech-2004-10-27-remarks-lititz-pennsylvania
# bush-speech-2004-10-27-remarks-vienna-ohio
# bush-speech-2004-10-27-findlay-ohio-0
# bush-speech-2004-10-27-pontiac-michigan-0
# bush-speech-2004-10-28-remarks-yardley-pennsylvania
# bush-speech-2004-10-28-dayton-ohio-1
# bush-speech-2004-10-28-remarks-westlake-ohio
# bush-speech-2004-10-28-saginaw-michigan-0
# bush-speech-2004-10-29-columbus-ohio-2
# bush-speech-2004-10-29-remarks-toledo-ohio
# bush-speech-2004-10-29-new-hampshire-2
# bush-speech-2004-10-29-new-hampshire-2
# bush-speech-2004-10-29-usama-bin-laden
# bush-speech-2004-10-30-ashwaubenon-wisconsin-0
# bush-speech-2004-10-30-minneapolis-minnesota-0
# bush-speech-2004-10-30-grand-rapids-michigan
# bush-speech-2004-10-30-orlando-florida-0
# bush-speech-2004-10-31-tampa-florida-2
# bush-speech-2004-10-31-cincinnati-ohio-1
# bush-speech-2004-10-31-remarks-miami-florida
# bush-speech-2004-10-31-remarks-gainesville-florida
# bush-speech-2004-11-01-dallas-texas-1
# bush-speech-2004-11-01-new-mexico-3
# bush-speech-2004-11-01-city-iowa-0
# bush-speech-2004-11-01-remarks-milwaukee-wisconsin
# bush-speech-2004-11-01-arrival-pittsburgh-pennsylvania
# bush-speech-2004-11-01-remarks-burgettstown-pennsylvania
# bush-speech-2004-11-01-remarks-wilmington-ohio
# bush-speech-2004-11-01-des-moines-iowa
# bush-speech-2004-11-02-reporters-columbus-ohio
# bush-speech-2004-11-02-reporters-crawford-texas
# kerry-speech-2004-07-29-national-convention-boston
# kerry-speech-2004-08-05-conference-washington-dc
# kerry-speech-2004-08-12-remarks-carson-california
# kerry-speech-2004-08-18-convention-cincinnati-ohio
# kerry-speech-2004-08-19-fire-fighters-boston
# kerry-speech-2004-08-24-new-york-city
# kerry-speech-2004-09-06-racine-west-virginia
# kerry-speech-2004-09-08-cincinnati-ohio-5
# kerry-speech-2004-09-09-convention-new-orleans
# kerry-speech-2004-09-11-annual-legislative-conference
# kerry-speech-2004-09-11-anniversary-commemoration-boston
# kerry-speech-2004-09-14-milwaukee-wisconsin-0
# kerry-speech-2004-09-15-gala-washington-dc
# kerry-speech-2004-09-15-economic-club-2
# kerry-speech-2004-09-16-general-conference-las
# kerry-speech-2004-09-20-new-york-university
# kerry-speech-2004-09-24-temple-university-philadelphia
# kerry-speech-2004-10-02-orlando-florida-4
# kerry-speech-2004-10-03-church-cleveland-ohio
# kerry-speech-2004-10-11-fe-new-mexico
# kerry-speech-2004-10-14-people-las-vegas
# kerry-speech-2004-10-15-area-technical-college
# kerry-speech-2004-10-16-school-xenia-ohio
# kerry-speech-2004-10-17-conference-washington-dc
# kerry-speech-2004-10-18-tampa-florida-7
# kerry-speech-2004-10-19-barre-pennsylvania-1
# kerry-speech-2004-10-20-waterloo-iowa-0
# kerry-speech-2004-10-21-columbus-ohio-9
# kerry-speech-2004-10-22-milwaukee-wisconsin-1
# kerry-speech-2004-10-24-fort-lauderdale-florida
# kerry-speech-2004-10-26-wisconsin-green-bay
# kerry-speech-2004-10-27-sioux-city-iowa
# kerry-speech-2004-10-29-orlando-florida-2
# obama-speech-2008-08-28-national-convention-denver
# obama-speech-2008-09-06-expo-washington-dc
# obama-speech-2008-09-09-dayton-ohio-4
# obama-speech-2008-09-10-gala-washington-dc
# obama-speech-2008-09-12-dover-new-hampshire
# obama-speech-2008-09-16-remarks-golden-colorado
# obama-speech-2008-09-17-remarks-elko-nevada
# obama-speech-2008-09-18-espanola-new-mexico
# obama-speech-2008-09-19-coral-gables-florida
# obama-speech-2008-09-20-beach-florida-1
# obama-speech-2008-09-21-north-carolina-0
# obama-speech-2008-09-22-green-bay-wisconsin
# obama-speech-2008-09-23-tampa-florida-4
# obama-speech-2008-09-23-president-ahmadinejads-remarks
# obama-speech-2008-09-24-remarks-dunedin-florida
# obama-speech-2008-09-25-new-york-city
# obama-speech-2008-09-27-north-carolina-1
# obama-speech-2008-09-28-remarks-detroit-michigan
# obama-speech-2008-09-29-remarks-westminster-colorado
# obama-speech-2008-09-30-reno-nevada-1
# obama-speech-2008-10-01-crosse-wisconsin-1
# obama-speech-2008-10-02-rapids-michigan-2
# obama-speech-2008-10-03-remarks-abington-pennsylvania
# obama-speech-2008-10-04-newport-news-virginia
# obama-speech-2008-10-05-north-carolina-1
# obama-speech-2008-10-08-indianapolis-indiana-5
# obama-speech-2008-10-09-dayton-ohio-2
# obama-speech-2008-10-10-chillicothe-ohio-1
# obama-speech-2008-10-11-philadelphia-pennsylvania-2
# obama-speech-2008-10-13-toledo-ohio-1
# obama-speech-2008-10-15-londonderry-new-hampshire
# obama-speech-2008-10-16-new-york-city
# obama-speech-2008-10-17-roanoke-virginia-0
# obama-speech-2008-10-18-louis-missouri-3
# obama-speech-2008-10-19-north-carolina-0
# obama-speech-2008-10-20-tampa-bay-florida
# obama-speech-2008-10-21-worth-florida-0
# obama-speech-2008-10-21-miami-florida-5
# obama-speech-2008-10-22-national-security-avail
# obama-speech-2008-10-22-richmond-virginia-0
# obama-speech-2008-10-23-indianapolis-indiana-3
# obama-speech-2008-10-24-west-virginia-1
# obama-speech-2008-10-25-reno-nevada-2
# obama-speech-2008-10-26-denver-colorado-3
# obama-speech-2008-10-27-campaign-closing-argument
# obama-speech-2008-10-28-remarks-chester-pennsylvania
# obama-speech-2008-10-29-raleigh-north-carolina
# obama-speech-2008-10-30-columbia-missouri-0
# obama-speech-2008-10-30-sarasota-florida-0
# obama-speech-2008-10-31-moines-iowa-1
# obama-speech-2008-11-02-columbus-ohio-6
# obama-speech-2008-11-03-jacksonville-florida-1
# mccain-speech-2008-09-04-national-convention-saint
# mccain-speech-2008-09-16-tampa-florida-5
# mccain-speech-2008-09-17-lake-orion-michigan
# mccain-speech-2008-09-18-rapids-iowa-3
# mccain-speech-2008-09-19-bay-wisconsin-0
# mccain-speech-2008-09-22-forum-scranton-pennsylvania
# mccain-speech-2008-09-23-corning-freeland-michigan
# mccain-speech-2008-09-24-new-york-city
# mccain-speech-2008-09-25-york-city-0
# mccain-speech-2008-09-28-columbus-ohio-7
# mccain-speech-2008-09-29-des-moines-iowa
# mccain-speech-2008-09-30-moines-iowa-3
# mccain-speech-2008-09-30-association-baltimore-maryland
# mccain-speech-2008-10-01-remarks-independence-missouri
# mccain-speech-2008-10-06-albquerque-new-mexico
# mccain-speech-2008-10-08-remarks-bethlehem-pennsylvania
# mccain-speech-2008-10-10-crosse-wisconsin-0
# mccain-speech-2008-10-13-virginia-beach-virginia
# mccain-speech-2008-10-14-blue-bell-pennsylvania
# mccain-speech-2008-10-16-york-city-0
# mccain-speech-2008-10-16-downingtown-pennsylvania-1
# mccain-speech-2008-10-17-miami-florida-4
# mccain-speech-2008-10-18-concord-north-carolina
# mccain-speech-2008-10-20-remarks-belton-missouri
# mccain-speech-2008-10-22-goffstown-new-hampshire
# mccain-speech-2008-10-24-denver-colorado-2
# mccain-speech-2008-10-27-dayton-ohio-3
# mccain-speech-2008-10-27-economy-cleveland-ohio
# mccain-speech-2008-10-28-hershey-pennsylvania-1
# mccain-speech-2008-10-29-miami-florida-2
# mccain-speech-2008-10-30-meeting-tampa-florida
# mccain-speech-2008-10-31-columbus-ohio-5
# mccain-speech-2008-11-03-miami-florida-3
# obama-speech-2012-09-06-democratic-national-convention
# obama-speech-2012-09-06-national-convention-charlotte
# obama-speech-2012-09-07-portsmouth-new-hampshire
# obama-speech-2012-09-07-iowa-city-iowa
# obama-speech-2012-09-08-rally-seminole-florida
# obama-speech-2012-09-08-rally-kissimmee-florida
# obama-speech-2012-09-09-rally-melbourne-florida
# obama-speech-2012-09-09-palm-beach-florida
# obama-speech-2012-09-11-arlington-virginia-3
# obama-speech-2012-09-12-mission-benghazi-libya
# obama-speech-2012-09-12-vegas-nevada-0
# obama-speech-2012-09-13-and-yom-kippur
# obama-speech-2012-09-13-rally-golden-colorado
# obama-speech-2012-09-14-and-paralympic-teams
# obama-speech-2012-09-14-mission-benghazi-libya
# obama-speech-2012-09-17-cincinnati-ohio-0
# obama-speech-2012-09-17-columbus-ohio-0
# obama-speech-2012-09-17-cio-convention-columbus
# obama-speech-2012-09-18-champion-minnesota-lynx
# obama-speech-2012-09-18-york-city-10
# obama-speech-2012-09-18-york-city-20
# obama-speech-2012-09-20-question-and-answer
# obama-speech-2012-09-20-fundraiser-tampa-florida
# obama-speech-2012-09-21-session-new-orleans
# obama-speech-2012-09-21-rally-woodbridge-virginia
# obama-speech-2012-09-22-milwaukee-wisconsin-0
# obama-speech-2012-09-22-campaign-rally-milwaukee
# obama-speech-2012-09-25-york-city-12
# obama-speech-2012-09-25-york-city-1
# obama-speech-2012-09-26-bowling-green-ohio
# obama-speech-2012-09-26-rally-kent-ohio
# obama-speech-2012-09-27-virginia-beach-virginia
# obama-speech-2012-09-28-2012-fundraiser-5
# obama-speech-2012-09-28-2012-fundraiser-6
# obama-speech-2012-09-28-2012-fundraiser-7
# obama-speech-2012-09-30-vegas-nevada-1
# obama-speech-2012-10-04-campaign-rally-denver
# obama-speech-2012-10-04-madison-wisconsin-0
# obama-speech-2012-10-05-rally-fairfax-virginia
# obama-speech-2012-10-05-cleveland-ohio-0
# obama-speech-2012-10-07-los-angeles-california
# obama-speech-2012-10-07-los-angeles-0
# obama-speech-2012-10-08-monument-keene-california
# obama-speech-2012-10-08-francisco-california-0
# obama-speech-2012-10-08-rally-san-francisco
# obama-speech-2012-10-09-columbus-ohio-1
# obama-speech-2012-10-11-rally-miami-florida
# obama-speech-2012-10-11-2012-fundraiser-miami
# obama-speech-2012-10-17-mount-vernon-iowa
# obama-speech-2012-10-17-rally-athens-ohio
# obama-speech-2012-10-18-manchester-new-hampshire
# obama-speech-2012-10-18-york-city-0
# obama-speech-2012-10-19-fairfax-virginia-0
# obama-speech-2012-10-23-delray-beach-florida
# obama-speech-2012-10-23-rally-dayton-ohio
# obama-speech-2012-10-24-rally-davenport-iowa
# obama-speech-2012-10-24-rally-denver-colorado
# obama-speech-2012-10-24-las-vegas-nevada
# obama-speech-2012-10-25-rally-tampa-florida
# obama-speech-2012-10-25-rally-richmond-virginia
# obama-speech-2012-10-25-rally-cleveland-ohio
# obama-speech-2012-10-27-nashua-new-hampshire
# obama-speech-2012-10-28-sandy-preparedness-efforts
# obama-speech-2012-10-29-and-exchange-with
# obama-speech-2012-10-30-sandy-relief-efforts
# obama-speech-2012-10-31-brigantine-new-jersey
# obama-speech-2012-11-01-green-bay-wisconsin
# obama-speech-2012-11-01-las-vegas-nevada
# obama-speech-2012-11-01-rally-boulder-colorado
# obama-speech-2012-11-02-rally-hilliard-ohio
# obama-speech-2012-11-02-rally-springfield-ohio
# obama-speech-2012-11-02-campaign-rally-springfield
# obama-speech-2012-11-02-rally-lima-ohio
# obama-speech-2012-11-03-management-agency-headquarters
# obama-speech-2012-11-03-rally-mentor-ohio
# obama-speech-2012-11-03-rally-milwaukee-wisconsin
# obama-speech-2012-11-03-rally-dubuque-iowa
# obama-speech-2012-11-03-rally-bristow-virginia
# obama-speech-2012-11-04-concord-new-hampshire
# obama-speech-2012-11-04-rally-hollywood-florida
# obama-speech-2012-11-04-rally-cincinnati-ohio
# obama-speech-2012-11-04-denver-colorado-0
# obama-speech-2012-11-05-rally-madison-wisconsin
# obama-speech-2012-11-05-rally-columbus-ohio
# obama-speech-2012-11-05-des-moines-iowa
# romney-speech-2012-08-30-national-convention-tampa
# romney-speech-2012-08-31-victory-rally-lakeland
# romney-speech-2012-09-01-event-cincinnati-ohio
# romney-speech-2012-09-01-event-jacksonville-florida
# romney-speech-2012-09-06-new-hampshire-0
# romney-speech-2012-09-07-orange-city-iowa
# romney-speech-2012-09-07-nashua-new-hampshire
# romney-speech-2012-09-08-virginia-beach-virginia
# romney-speech-2012-09-10-event-mansfield-ohio
# romney-speech-2012-09-11-general-conference-and
# romney-speech-2012-09-12-exchange-with-reporters
# romney-speech-2012-09-13-event-fairfax-virginia
# romney-speech-2012-09-14-event-painseville-ohio
# romney-speech-2012-09-17-los-angeles-california
# romney-speech-2012-09-20-event-sarasota-florida
# romney-speech-2012-09-21-las-vegas-nevada
# romney-speech-2012-09-23-event-denver-colorado
# romney-speech-2012-09-24-event-pueblo-colorado
# romney-speech-2012-09-25-york-city-1
# romney-speech-2012-09-25-new-york-city
# romney-speech-2012-09-25-event-vandalia-ohio
# romney-speech-2012-09-26-event-westerville-ohio
# romney-speech-2012-09-26-event-toledo-ohio
# romney-speech-2012-09-27-event-springfield-virginia
# romney-speech-2012-09-28-event-wayne-pennsylvania
# romney-speech-2012-10-01-denver-colorado-0
# romney-speech-2012-10-04-committee-conference-denver
# romney-speech-2012-10-04-event-fishersville-virginia
# romney-speech-2012-10-05-event-abingdon-virginia
# romney-speech-2012-10-05-st-petersburg-florida
# romney-speech-2012-10-06-event-apopka-florida
# romney-speech-2012-10-07-st-lucie-florida
# romney-speech-2012-10-08-virginia-the-mantle
# romney-speech-2012-10-08-newport-news-virginia
# romney-speech-2012-10-09-van-meter-iowa
# romney-speech-2012-10-09-event-cuyahoga-falls
# romney-speech-2012-10-10-mount-vernon-ohio
# romney-speech-2012-10-10-event-delaware-ohio
# romney-speech-2012-10-10-event-sidney-ohio
# romney-speech-2012-10-11-asheville-north-carolina
# romney-speech-2012-10-12-event-richmond-virginia
# romney-speech-2012-10-12-event-lancaster-ohio
# romney-speech-2012-10-13-remarks-portsmouth-ohio
# romney-speech-2012-10-17-rally-leesburg-virginia
# romney-speech-2012-10-17-rally-chesapeake-virginia
# romney-speech-2012-10-18-new-york-city
# romney-speech-2012-10-19-daytona-beach-florida
# romney-speech-2012-10-23-event-henderson-nevada
# romney-speech-2012-10-23-event-morrison-colorado
# romney-speech-2012-10-24-event-reno-nevada
# romney-speech-2012-10-26-economy-ames-iowa
# romney-speech-2012-11-02-from-day-one
# trump-speech-2016-07-21-national-convention-cleveland
# trump-speech-2016-08-05-green-bay-wisconsin
# trump-speech-2016-08-08-economic-club-1
# trump-speech-2016-08-09-north-carolina-wilmington
# trump-speech-2016-08-12-arena-erie-pennsylvania
# trump-speech-2016-08-15-university-youngstown-ohio
# trump-speech-2016-08-16-west-bend-wisconsin
# trump-speech-2016-08-18-charlotte-north-carolina
# trump-speech-2016-08-19-complex-dimondale-michigan
# trump-speech-2016-08-23-arena-austin-texas
# trump-speech-2016-08-24-coliseum-jackson-mississippi
# trump-speech-2016-08-30-arena-everett-washington
# trump-speech-2016-08-31-center-phoenix-arizona
# trump-speech-2016-09-07-philadelphia-philadelphia-pennsylvania
# trump-speech-2016-09-12-asheville-north-carolina
# trump-speech-2016-09-30-showplace-novi-michigan
# trump-speech-2016-10-03-center-pueblo-colorado
# trump-speech-2016-10-03-center-loveland-colorado
# trump-speech-2016-10-04-prescott-valley-arizona
# trump-speech-2016-10-05-pavilion-henderson-nevada
# trump-speech-2016-10-05-center-reno-nevada
# trump-speech-2016-10-11-panama-city-florida
# trump-speech-2016-10-12-pavilion-ocala-florida
# trump-speech-2016-10-13-hotel-columbus-ohio
# trump-speech-2016-10-13-palm-beach-florida
# trump-speech-2016-10-15-center-bangor-maine
# trump-speech-2016-10-15-portsmouth-new-hampshire
# trump-speech-2016-10-17-bay-wisconsin-0
# trump-speech-2016-10-18-colorado-springs-colorado
# trump-speech-2016-10-20-fairgrounds-delaware-ohio
# trump-speech-2016-10-21-fletcher-north-carolina
# trump-speech-2016-10-21-center-newtown-pennsylvania
# trump-speech-2016-10-22-eisenhower-complex-gettysburg
# trump-speech-2016-10-23-fairgrounds-naples-florida
# trump-speech-2016-10-26-charlotte-north-carolina
# trump-speech-2016-10-27-expo-springfield-ohio
# trump-speech-2016-10-28-manchester-new-hampshire
# trump-speech-2016-10-29-center-golden-colorado
# trump-speech-2016-10-29-center-phoenix-arizona
# trump-speech-2016-10-31-campus-warren-michigan
# trump-speech-2016-11-01-valley-forge-pennsylvania
# trump-speech-2016-11-02-fairgrounds-orlando-florida
# trump-speech-2016-11-02-amphitheater-miami-florida
# trump-speech-2016-11-07-raleigh-north-carolina
# clinton-speech-2016-07-28-democratic-national-convention
# clinton-speech-2016-09-15-institute-washington-dc
# clinton-speech-2016-09-15-north-carolina-greensboro
# clinton-speech-2016-09-16-symposium-washington-dc
# clinton-speech-2016-09-18-caucus-washington-dc
# clinton-speech-2016-09-19-university-philadelphia-pennsylvania
# clinton-speech-2016-09-21-center-orlando-florida
# clinton-speech-2016-09-27-raleigh-north-carolina
# clinton-speech-2016-09-28-new-hampshire-durham
# clinton-speech-2016-09-29-des-moines-iowa
# clinton-speech-2016-09-30-coral-springs-florida
# clinton-speech-2016-09-30-fort-pierce-florida
# clinton-speech-2016-10-02-charlotte-north-carolina
# clinton-speech-2016-10-03-theater-akron-ohio
# clinton-speech-2016-10-03-plaza-toledo-ohio
# clinton-speech-2016-10-10-state-university-columbus
# clinton-speech-2016-10-11-college-miami-florida
# clinton-speech-2016-10-12-state-fairgrounds-pueblo
# clinton-speech-2016-10-20-the-waldorf-astoria
# clinton-speech-2016-10-21-college-cleveland-ohio
# clinton-speech-2016-10-22-plane-pittsburgh-pennsylvania
# clinton-speech-2016-10-22-school-pittsburgh-pennsylvania
# clinton-speech-2016-10-24-manchester-new-hampshire
# clinton-speech-2016-10-25-coconut-creek-florida
# clinton-speech-2016-10-26-park-tampa-florida
# clinton-speech-2016-10-27-salem-north-carolina
# clinton-speech-2016-10-29-daytona-beach-florida
# clinton-speech-2016-10-30-wilton-manors-florida
# clinton-speech-2016-10-31-park-cincinnati-ohio
# clinton-speech-2016-10-31-center-kent-ohio
# clinton-speech-2016-11-03-dade-city-florida
# clinton-speech-2016-11-03-raleigh-north-carolina
# clinton-speech-2016-11-03-winterville-north-carolina
# clinton-speech-2016-11-04-market-detroit-michigan
# clinton-speech-2016-11-07-grand-rapids-michigan
# clinton-speech-2016-11-07-state-university-raleigh
# clinton-speech-2016-11-07-the-university-pittsburgh

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-83c082d811dc> in <module>
#      10              10: {'first': 'Hillary', 'last': 'Clinton', 'title': 'Secretary', 'start': date(2016, 7, 28), 'end': date(2016, 11, 8)}}
#      11
# ---> 12 for filename in os.listdir(directory):
#      13     if filename.endswith(".asm") or filename.endswith(".py"):
#      14          # print(os.path.join(directory, filename))
#
# NameError: name 'directory' is not defined
