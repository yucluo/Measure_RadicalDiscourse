# %%
import pandas as pd
import numpy as np
import string
import re
import random 
import os
import csv

from gensim.models.word2vec import Word2Vec

from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn import metrics
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline

from imblearn.ensemble import BalancedRandomForestClassifier

import gensim
import gensim.downloader as gensim_api
from numpy import asarray
from numpy import savetxt
from numpy import loadtxt

# %% [markdown]
# # Tf-idf RF

# %%
auc_scores = []
pr_auc = []

dat = pd.read_csv("20220115_all_paragraphs_2020_added.csv")
annotated = pd.read_csv("All_annotated_data_inclusion.csv")
dat = dat.merge(annotated[["speech_par_id", "pred_class"]], how = "left", on = "speech_par_id")

for filename in os.listdir("/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/"):
    ## load the test set 
    file = "/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/" + "/" + filename
    test = pd.read_csv(file)
    train = annotated[~annotated['speech_par_id'].isin(test["speech_par_id"])]
    test = test[test['speech_par_id'].isin(dat['speech_par_id'])]
    train = train[train['speech_par_id'].isin(dat['speech_par_id'])] # make sure annotated data and the original df match
    # pipeline BOW, tfidf and RF
    text_clf = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('clf', RandomForestClassifier(n_estimators=5000, max_depth=3,max_features='sqrt', random_state=0, class_weight="balanced")),
                                                 ])
      ## Fit the model to the training set
    text_clf = text_clf.fit(train['text'], train['pred_class'])
    ## Predict out-of-sample on the test set and compute AUC
    preds = text_clf.predict_proba(test['text'])
    fpr_d2v, tpr_d2v, thresholds_d2v = metrics.roc_curve(test['true_class'], preds[:,1], pos_label=1)
    auc_scores = auc_scores + [metrics.auc(fpr_d2v, tpr_d2v)]
    #PR AUC
    lr_precision, lr_recall, _ = precision_recall_curve(test['true_class'],  preds[:,1].tolist())
    lr_auc = auc(lr_recall, lr_precision)
    pr_auc = pr_auc + [lr_auc]
    print("AUC: "+str(metrics.auc(fpr_d2v, tpr_d2v)))
    print("PR AUC: " + str(lr_auc))
    
print("Mean AUC: " + str(np.mean(auc_scores)))
print("Mean PR AUC: " + str(np.mean(pr_auc)))

confusion = confusion_matrix(test['true_class'],text_clf.predict(test['text']) )
print(confusion)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# AUC: 0.8008760107816711
# PR AUC: 0.3769929657730592
# AUC: 0.8194070080862534
# PR AUC: 0.4423001129680347
# AUC: 0.8432961837217156
# PR AUC: 0.34822579834716283
# AUC: 0.8692722371967655
# PR AUC: 0.3395916838914933
# AUC: 0.8365902964959568
# PR AUC: 0.2654298378987005
# AUC: 0.8700889339187211
# PR AUC: 0.38275414391609686
# AUC: 0.8176100628930817
# PR AUC: 0.2812387616868936
# AUC: 0.8460242587601078
# PR AUC: 0.3919382258010612
# AUC: 0.7820080862533693
# PR AUC: 0.3299094982329371
# AUC: 0.8190700808625336
# PR AUC: 0.31370830668970834
# AUC: 0.8605200945626479
# PR AUC: 0.34683880123571453
# AUC: 0.8222447371383541
# PR AUC: 0.43622051156480424
# AUC: 0.8490566037735848
# PR AUC: 0.3136191888081996
# AUC: 0.7574123989218329
# PR AUC: 0.34711870937300077
# AUC: 0.7756064690026954
# PR AUC: 0.2751365413994735
# AUC: 0.7687556154537287
# PR AUC: 0.26890974772573195
# AUC: 0.8548966756513926
# PR AUC: 0.40202110023195003
# AUC: 0.9156558849955075
# PR AUC: 0.46912516237637475
# AUC: 0.7930143755615453
# PR AUC: 0.24599736419801382
# AUC: 0.7999775381850853
# PR AUC: 0.4202235204824718
# AUC: 0.839622641509434
# PR AUC: 0.2627487628361374
# AUC: 0.8451257861635221
# PR AUC: 0.34504859586017694
# AUC: 0.8297394429469902
# PR AUC: 0.3207737181219079
# AUC: 0.8892632524707996
# PR AUC: 0.516458622342014
# AUC: 0.8969002695417789
# PR AUC: 0.47671730809796586
# Mean AUC: 0.832081397793963
# Mean PR AUC: 0.3567618795943634
# [[423   1]
#  [ 20   1]]

# %%
with open("inclusion_pr_auc_tfidf.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in pr_auc:
        csvwriter.writerow([row])    
    
with open("inclusion_auc_tfidf.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in auc_scores:
        csvwriter.writerow([row])

# %% [markdown]
# # Local Word2Vec RF

# %%
auc_scores = []
pr_auc = []

dat = pd.read_csv("20220131_all_paragraphs_2020_added_missings_added.csv")
annotated = pd.read_csv("All_annotated_data_round_1_inclusion_20220209.csv")
dat = dat.merge(annotated[["speech_par_id", "pred_class"]], how = "left", on = "speech_par_id")
avg_embeddings = loadtxt('avg_embeddings.csv', delimiter=',')

for filename in os.listdir("/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/"):
    ## load the test set 
    file = "/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/" + "/" + filename
    test = pd.read_csv(file)
    train = annotated[~annotated['speech_par_id'].isin(test["speech_par_id"])]
    test = test[test['speech_par_id'].isin(dat['speech_par_id'])]
    train = train[train['speech_par_id'].isin(dat['speech_par_id'])] # make sure annotated data and the original df match
    # attach train/test set to original df
    train_id = train['speech_par_id']
    test_id = test['speech_par_id']    
    dat['test'] = np.where(dat['speech_par_id'].isin(test_id), 1, 0)
    dat['train'] = np.where(dat['speech_par_id'].isin(train_id), 1, 0)
    # get the embeddings to train/test set
    train_vec = np.asarray([avg_embeddings[i] for i in dat[dat['speech_par_id'].isin(train_id)].index.tolist()])
    test_vec = np.asarray([avg_embeddings[i] for i in dat[dat['speech_par_id'].isin(test_id)].index.tolist()])
    ## Fit the model to the training set
    text_clf = RandomForestClassifier(n_estimators=5000, max_depth=10, random_state=0, max_features = 0.2, class_weight="balanced")
    text_clf.fit(train_vec,  dat[dat['train']==1].pred_class) # use the original df to match the order
    ## Predict out-of-sample on the test set and compute AUC
    preds = text_clf.predict_proba(test_vec)
    fpr_d2v, tpr_d2v, thresholds_d2v = metrics.roc_curve(dat[dat['test']==1].pred_class, preds[:,1], pos_label=1)
    auc_scores = auc_scores + [metrics.auc(fpr_d2v, tpr_d2v)]
    #PR AUC
    lr_precision, lr_recall, _ = precision_recall_curve(dat[dat['test']==1].pred_class,  preds[:,1].tolist())
    lr_auc = auc(lr_recall, lr_precision)
    pr_auc = pr_auc + [lr_auc]
    print("AUC: "+str(metrics.auc(fpr_d2v, tpr_d2v)))
    print("PR AUC: " + str(lr_auc))
    
print("Mean AUC: " + str(np.mean(auc_scores)))
print("Mean PR AUC: " + str(np.mean(pr_auc)))

confusion = confusion_matrix(dat[dat['test']==1].pred_class,text_clf.predict(test_vec) )
print(confusion)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# AUC: 0.6692558820218395
# PR AUC: 0.08835575939315282
# AUC: 0.7770664869721473
# PR AUC: 0.14093415898329587
# AUC: 0.7492138364779874
# PR AUC: 0.19642432709541502
# AUC: 0.6686834733893557
# PR AUC: 0.126081337609296
# AUC: 0.6676750700280112
# PR AUC: 0.10438285687734145
# AUC: 0.7645797598627787
# PR AUC: 0.1535680754926754
# AUC: 0.7619815173006662
# PR AUC: 0.11619906060024518
# AUC: 0.5785207700101317
# PR AUC: 0.08032107636866795
# AUC: 0.76258020938872
# PR AUC: 0.16309325601911492
# AUC: 0.6670028011204482
# PR AUC: 0.20604149006221517
# AUC: 0.7413522012578617
# PR AUC: 0.15093338333603548
# AUC: 0.701707097933513
# PR AUC: 0.1528667389561688
# AUC: 0.521344537815126
# PR AUC: 0.08596608329849231
# AUC: 0.7509648370497428
# PR AUC: 0.12541543027869212
# AUC: 0.7574690567648314
# PR AUC: 0.10932070052897928
# AUC: 0.7625668449197861
# PR AUC: 0.14144319116966866
# AUC: 0.6786273194723899
# PR AUC: 0.12810965515660594
# AUC: 0.7306828391734052
# PR AUC: 0.1562987203493045
# AUC: 0.8515537670467248
# PR AUC: 0.21218947550572068
# AUC: 0.7334759358288769
# PR AUC: 0.12121935178100918
# AUC: 0.6449399656946827
# PR AUC: 0.08082878131389623
# AUC: 0.6936208445642408
# PR AUC: 0.0860132553056692
# AUC: 0.7149564050972502
# PR AUC: 0.12653849905736103
# AUC: 0.714733893557423
# PR AUC: 0.15063185091305417
# AUC: 0.7353819889031157
# PR AUC: 0.10975560967028077
# Mean AUC: 0.7119974936660423
# Mean PR AUC: 0.13251728500489432
# [[423   3]
#  [ 22   0]]

# %%
with open("inclusion_pr_auc_w2v.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in pr_auc:
        csvwriter.writerow([row])    
    
with open("inclusion_auc_w2v.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in auc_scores:
        csvwriter.writerow([row])

# %% [markdown]
# # Pretrained Word2Vec

# %%
auc_scores = []
pr_auc = []

dat = pd.read_csv("20220131_all_paragraphs_2020_added_missings_added.csv")
annotated = pd.read_csv("All_annotated_data_round_1_inclusion_20220209.csv")
dat = dat.merge(annotated[["speech_par_id", "pred_class"]], how = "left", on = "speech_par_id")
avg_embeddings = loadtxt('avg_embeddings_pretrained.csv', delimiter=',')

for filename in os.listdir("/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/"):
    ## load the test set 
    file = "/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/" + "/" + filename
    test = pd.read_csv(file)
    train = annotated[~annotated['speech_par_id'].isin(test["speech_par_id"])]
    test = test[test['speech_par_id'].isin(dat['speech_par_id'])]
    train = train[train['speech_par_id'].isin(dat['speech_par_id'])] # make sure annotated data and the original df match
# attach train/test set to original df
    train_id = train['speech_par_id']
    test_id = test['speech_par_id']    
    dat['test'] = np.where(dat['speech_par_id'].isin(test_id), 1, 0)
    dat['train'] = np.where(dat['speech_par_id'].isin(train_id), 1, 0)
    # get the embeddings to train/test set
    train_vec = np.asarray([avg_embeddings[i] for i in dat[dat['speech_par_id'].isin(train_id)].index.tolist()])
    test_vec = np.asarray([avg_embeddings[i] for i in dat[dat['speech_par_id'].isin(test_id)].index.tolist()])
    ## Fit the model to the training set
    text_clf = RandomForestClassifier(n_estimators=5000, max_depth=10, random_state=0, max_features = "sqrt", class_weight="balanced")
    text_clf.fit(train_vec,  dat[dat['train']==1].pred_class) # use the original df to match the order
    ## Predict out-of-sample on the test set and compute AUC
    preds = text_clf.predict_proba(test_vec)
    fpr_d2v, tpr_d2v, thresholds_d2v = metrics.roc_curve(dat[dat['test']==1].pred_class, preds[:,1], pos_label=1)
    auc_scores = auc_scores + [metrics.auc(fpr_d2v, tpr_d2v)]
    #PR AUC
    lr_precision, lr_recall, _ = precision_recall_curve(dat[dat['test']==1].pred_class,  preds[:,1].tolist())
    lr_auc = auc(lr_recall, lr_precision)
    pr_auc = pr_auc + [lr_auc]
    print("AUC: "+str(metrics.auc(fpr_d2v, tpr_d2v)))
    print("PR AUC: " + str(lr_auc))
    
print("Mean AUC: " + str(np.mean(auc_scores)))
print("Mean PR AUC: " + str(np.mean(pr_auc)))

confusion = confusion_matrix(dat[dat['test']==1].pred_class,text_clf.predict(test_vec) )
print(confusion)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# AUC: 0.6637397275695148
# PR AUC: 0.08615386104540723
# AUC: 0.7759433962264151
# PR AUC: 0.20542096200643092
# AUC: 0.7288858939802336
# PR AUC: 0.24590209849945247
# AUC: 0.6886274509803921
# PR AUC: 0.1474433526939402
# AUC: 0.6804481792717086
# PR AUC: 0.18419200431771193
# AUC: 0.7480703259005146
# PR AUC: 0.16501373794986982
# AUC: 0.708575112830432
# PR AUC: 0.13712901679071246
# AUC: 0.5725543172351683
# PR AUC: 0.15288261273322176
# AUC: 0.703253405381065
# PR AUC: 0.09610424827566443
# AUC: 0.6431372549019608
# PR AUC: 0.29340541948044613
# AUC: 0.6851976639712488
# PR AUC: 0.1537888440145659
# AUC: 0.6115229110512129
# PR AUC: 0.07494482884463063
# AUC: 0.5845378151260503
# PR AUC: 0.05847761815393647
# AUC: 0.6740994854202401
# PR AUC: 0.11914535176395663
# AUC: 0.7373026034997866
# PR AUC: 0.13217424365986336
# AUC: 0.7188235294117648
# PR AUC: 0.10872932471306232
# AUC: 0.6825396825396826
# PR AUC: 0.12440212854308672
# AUC: 0.6331985624438454
# PR AUC: 0.18370575610973305
# AUC: 0.8057232282584396
# PR AUC: 0.14675381414223052
# AUC: 0.8094117647058824
# PR AUC: 0.13919203062265653
# AUC: 0.6842838765008576
# PR AUC: 0.13759041338436961
# AUC: 0.6410601976639712
# PR AUC: 0.08585608439752059
# AUC: 0.7284820031298903
# PR AUC: 0.13491738359707012
# AUC: 0.7817366946778712
# PR AUC: 0.30034861768086085
# AUC: 0.7188433632095604
# PR AUC: 0.10661460458574158
# Mean AUC: 0.6963999378355084
# Mean PR AUC: 0.14881153432024571
# [[426   0]
#  [ 22   0]]

# %%
with open("inclusion_pr_auc_pretrained.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in pr_auc:
        csvwriter.writerow([row])    
    
with open("inclusion_auc_pretrained.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in auc_scores:
        csvwriter.writerow([row])

# %% [markdown]
# # RFC

# %%
auc_scores_d2v = []
pr_auc = []
accuracy_scores_d2v = []

dat = pd.read_csv("20201115_all_paragraphs.csv")
dat['speech_par_id'] = dat['Speech_id'].astype(str) + "_" + dat['par_id'].astype(str)

model = Word2Vec.load("doc2vec_wordvecs.model") 
annotated = pd.read_csv("All_annotated_data_round_1_inclusion_20220209.csv")
dat = dat.merge(annotated[["speech_par_id", "pred_class"]], how = "left", on = "speech_par_id")

for filename in os.listdir("/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/"):
    ## load the test set 
    file = "/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/" + "/" + filename
    test = pd.read_csv(file)
    train = annotated[~annotated['speech_par_id'].isin(test["speech_par_id"])]
    test = test[test['speech_par_id'].isin(dat['speech_par_id'])]
    train = train[train['speech_par_id'].isin(dat['speech_par_id'])] # make sure annotated data and the original df match
    # merge test and train sets back onto the total df
    dat['test'] = np.where(dat['speech_par_id'].isin(test["speech_par_id"]), 1, 0)
    dat['train'] = np.where(dat['speech_par_id'].isin(train["speech_par_id"]), 1, 0)
    # so that teh order of rows are the same with the embeddings
    test_set = np.asarray([model.docvecs[i] for i in dat[dat['test'] == 1].index.tolist()])
    train_set = np.asarray([model.docvecs[i] for i in dat[dat['train']== 1].index.tolist()])
    ## Initialize a random forest classifier
    gbc = RandomForestClassifier(n_estimators=500, max_depth=10, random_state=0, max_features = "sqrt", class_weight="balanced")
    ## Fit the model to the training set
    gbc.fit(train_set, dat[dat['train']==1].pred_class)
    ## Predict out-of-sample on the test set and compute AUC
    preds = gbc.predict_proba(test_set)
    fpr_d2v, tpr_d2v, thresholds_d2v = metrics.roc_curve(dat[dat['test']==1].pred_class, preds[:,1], pos_label=1)
    auc_scores_d2v = auc_scores_d2v + [metrics.auc(fpr_d2v, tpr_d2v)]
    #PR AUC
    lr_precision, lr_recall, _ = precision_recall_curve(dat[dat['test']==1].pred_class,  preds[:,1].tolist())
    lr_auc = auc(lr_recall, lr_precision)
    pr_auc = pr_auc + [lr_auc]
    print("AUC: "+str(metrics.auc(fpr_d2v, tpr_d2v)))
    accuracy_d2v = metrics.accuracy_score(dat[dat['test']==1].pred_class, gbc.predict(test_set))
    accuracy_scores_d2v = accuracy_scores_d2v + [accuracy_d2v]
    print("Accuracy: " + str(accuracy_d2v))
    print("PR_AUC: " + str(lr_auc))

print("Mean AUC: " + str(np.mean(auc_scores_d2v)))
print("Mean Accuracy: " + str(np.mean(accuracy_scores_d2v)))

confusion = confusion_matrix(dat[dat['test']==1].pred_class, gbc.predict(test_set))
print(confusion)
# Out:
# AUC: 0.7757514353259034
# Accuracy: 0.9527027027027027
# PR_AUC: 0.1381569452361355
# AUC: 0.762915543575921
# Accuracy: 0.952808988764045
# PR_AUC: 0.1589216940398971
# AUC: 0.7470799640610961
# Accuracy: 0.952808988764045
# PR_AUC: 0.19291021921282245
# AUC: 0.7892436974789916
# Accuracy: 0.952914798206278
# PR_AUC: 0.23916942696900031
# AUC: 0.6732773109243697
# Accuracy: 0.952914798206278
# PR_AUC: 0.15138945534655146
# AUC: 0.7162307032590052
# Accuracy: 0.9506726457399103
# PR_AUC: 0.12315999166886088
# AUC: 0.7295293359123146
# Accuracy: 0.950561797752809
# PR_AUC: 0.09889346703706488
# AUC: 0.7066306428008555
# Accuracy: 0.9527027027027027
# PR_AUC: 0.12702033388004305
# AUC: 0.7893729595857255
# Accuracy: 0.9527027027027027
# PR_AUC: 0.13986321264331655
# AUC: 0.6994957983193277
# Accuracy: 0.952914798206278
# PR_AUC: 0.13389499152107892
# AUC: 0.798292902066487
# Accuracy: 0.952808988764045
# PR_AUC: 0.21966865073839412
# AUC: 0.7046043003489812
# Accuracy: 0.9527027027027027
# PR_AUC: 0.10486898147303236
# AUC: 0.5930532212885153
# Accuracy: 0.952914798206278
# PR_AUC: 0.1558588140317538
# AUC: 0.7296367934665806
# Accuracy: 0.950561797752809
# PR_AUC: 0.13225655074832823
# AUC: 0.7270593256508749
# Accuracy: 0.9508928571428571
# PR_AUC: 0.1416527161346055
# AUC: 0.706524064171123
# Accuracy: 0.9507829977628636
# PR_AUC: 0.1106275507171412
# AUC: 0.7146210596914823
# Accuracy: 0.9530201342281879
# PR_AUC: 0.1772962158714296
# AUC: 0.7419790611279973
# Accuracy: 0.9527027027027027
# PR_AUC: 0.20056117303983295
# AUC: 0.8352941176470587
# Accuracy: 0.952914798206278
# PR_AUC: 0.28766189942404935
# AUC: 0.8062032085561497
# Accuracy: 0.9507829977628636
# PR_AUC: 0.1198785575142979
# AUC: 0.7168739279588336
# Accuracy: 0.9506726457399103
# PR_AUC: 0.15395205778130372
# AUC: 0.7608939802336029
# Accuracy: 0.952808988764045
# PR_AUC: 0.09927214447479676
# AUC: 0.7653781512605041
# Accuracy: 0.952914798206278
# PR_AUC: 0.1399229408995178
# AUC: 0.7055256064690028
# Accuracy: 0.952808988764045
# PR_AUC: 0.10591237244655408
# AUC: 0.7576824583866837
# Accuracy: 0.9508928571428571
# PR_AUC: 0.13976897400661722
# Mean AUC: 0.7381259827826955
# Mean Accuracy: 0.952155519103859
# [[426   0]
#  [ 22   0]]

# %%
with open("inclusion_pr_auc_d2v.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in pr_auc:
        csvwriter.writerow([row])
    
    
with open("inclusion_auc_d2v.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in auc_scores_d2v:
        csvwriter.writerow([row])

# %%
print("Mean ROC-AUC: " + str(np.mean(auc_scores_d2v)))
print("Mean Accuracy: " + str(np.mean(accuracy_scores_d2v)))
print("Mean PR_AUC: " + str(np.mean(pr_auc)))
# Out:
# Mean ROC-AUC: 0.7381259827826955
# Mean Accuracy: 0.952155519103859
# Mean PR_AUC: 0.15170157347425703

# %% [markdown]
# # balanced RFC

# %%
auc_scores_balanced = []
pr_auc_balanced = []
accuracy_scores_balanced = []

dat = pd.read_csv("20201115_all_paragraphs.csv")
dat['speech_par_id'] = dat['Speech_id'].astype(str) + "_" + dat['par_id'].astype(str)
# X = np.asarray([model.docvecs[i] for i in label_dat.index.tolist()])
# Y = np.asarray(label_dat['label'].tolist(), dtype="int")
model = Word2Vec.load("doc2vec_wordvecs.model") 
dat = dat.merge(annotated[["speech_par_id", "pred_class"]], how = "left", on = "speech_par_id")
annotated = pd.read_csv("All_annotated_data_round_1_inclusion_20220209.csv")


for filename in os.listdir("/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/"):
    ## load the test set 
    file = "/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/" + "/" + filename
    test = pd.read_csv(file)
    train = annotated[~annotated['speech_par_id'].isin(test["speech_par_id"])]
    test = test[test['speech_par_id'].isin(dat['speech_par_id'])]
    train = train[train['speech_par_id'].isin(dat['speech_par_id'])] # make sure annotated data and the original df match
    # merge test and train sets back onto the total df
    dat['test'] = np.where(dat['speech_par_id'].isin(test["speech_par_id"]), 1, 0)
    dat['train'] = np.where(dat['speech_par_id'].isin(train["speech_par_id"]), 1, 0)
    # so that teh order of rows are the same with the embeddings
    test_set = np.asarray([model.docvecs[i] for i in dat[dat['test'] == 1].index.tolist()])
    train_set = np.asarray([model.docvecs[i] for i in dat[dat['train']== 1].index.tolist()])
    ## Initialize a random forest classifier
    brfc = BalancedRandomForestClassifier(n_estimators=5000, max_depth=3, random_state=0, max_features = "sqrt")
    ## Fit the model to the training set
    brfc.fit(train_set, dat[dat['train']==1].pred_class)
    ## Predict out-of-sample on the test set and compute AUC
    preds = brfc.predict_proba(test_set)
    fpr, tpr, thresholds = metrics.roc_curve(dat[dat['test']==1].pred_class, preds[:,1], pos_label=1)
    auc_scores_balanced = auc_scores_balanced + [metrics.auc(fpr, tpr)]
    #PR AUC
    lr_precision, lr_recall, _ = precision_recall_curve(dat[dat['test']==1].pred_class,  preds[:,1].tolist())
    lr_auc = auc(lr_recall, lr_precision)
    pr_auc_balanced = pr_auc_balanced + [lr_auc]
    print("AUC: "+str(metrics.auc(fpr, tpr)))
    accuracy_balanced = metrics.accuracy_score(dat[dat['test']==1].pred_class, brfc.predict(test_set))
    accuracy_scores_balanced = accuracy_scores_balanced + [accuracy_balanced]
    print("Accuracy: " + str(accuracy_balanced))
    print("PR_AUC: " + str(lr_auc))

print("Mean AUC: " + str(np.mean(auc_scores_balanced)))
print("Mean Accuracy: " + str(np.mean(accuracy_scores_balanced)))
# Out:
# AUC: 0.7368006304176516
# Accuracy: 0.7364864864864865
# PR_AUC: 0.10946197371301054
# AUC: 0.7926774483378256
# Accuracy: 0.7146067415730337
# PR_AUC: 0.21245099477727236
# AUC: 0.761455525606469
# Accuracy: 0.750561797752809
# PR_AUC: 0.24573932862484185
# AUC: 0.7759103641456582
# Accuracy: 0.7219730941704036
# PR_AUC: 0.17982567705172448
# AUC: 0.6899719887955182
# Accuracy: 0.6860986547085202
# PR_AUC: 0.16593029797321024
# AUC: 0.7749785591766724
# Accuracy: 0.7107623318385651
# PR_AUC: 0.17328563813972384
# AUC: 0.7303889963464432
# Accuracy: 0.7191011235955056
# PR_AUC: 0.1288904752354525
# AUC: 0.6697061803444782
# Accuracy: 0.7252252252252253
# PR_AUC: 0.1267287972071411
# AUC: 0.7981537768771811
# Accuracy: 0.7364864864864865
# PR_AUC: 0.15972674685399302
# AUC: 0.7247058823529411
# Accuracy: 0.7354260089686099
# PR_AUC: 0.27719100662275503
# AUC: 0.7955974842767297
# Accuracy: 0.7213483146067415
# PR_AUC: 0.22564895013186698
# AUC: 0.713272543059777
# Accuracy: 0.740990990990991
# PR_AUC: 0.10572932722377369
# AUC: 0.630812324929972
# Accuracy: 0.7376681614349776
# PR_AUC: 0.12323163427814302
# AUC: 0.7376961100365356
# Accuracy: 0.7078651685393258
# PR_AUC: 0.11434558252626326
# AUC: 0.7329278702518138
# Accuracy: 0.7209821428571429
# PR_AUC: 0.13228568101794852
# AUC: 0.7693048128342247
# Accuracy: 0.7539149888143176
# PR_AUC: 0.16619782313322756
# AUC: 0.7232282584395261
# Accuracy: 0.697986577181208
# PR_AUC: 0.21886053121436855
# AUC: 0.7300461555780705
# Accuracy: 0.7319819819819819
# PR_AUC: 0.24661771750699352
# AUC: 0.8685714285714285
# Accuracy: 0.7017937219730942
# PR_AUC: 0.37952452426633954
# AUC: 0.8119786096256685
# Accuracy: 0.7136465324384788
# PR_AUC: 0.17847760054630635
# AUC: 0.7180531732418525
# Accuracy: 0.7286995515695067
# PR_AUC: 0.1612596532092444
# AUC: 0.7608939802336028
# Accuracy: 0.748314606741573
# PR_AUC: 0.1082101132969259
# AUC: 0.7687394957983192
# Accuracy: 0.7242152466367713
# PR_AUC: 0.1462630988916453
# AUC: 0.7996406109613656
# Accuracy: 0.7101123595505618
# PR_AUC: 0.21442589130174117
# AUC: 0.7797695262483996
# Accuracy: 0.7165178571428571
# PR_AUC: 0.19884150157861136
# Mean AUC: 0.7518112694595251
# Mean Accuracy: 0.723710646130607

# %%
with open("inclusion_pr_auc_balanced.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in pr_auc_balanced:
        csvwriter.writerow([row])    
    
with open("inclusion_auc_balanced.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile)
    for row in auc_scores_balanced:
        csvwriter.writerow([row])

# %%
print("Mean ROC-AUC: " + str(np.mean(auc_scores_balanced)))
print("Mean Accuracy: " + str(np.mean(accuracy_scores_balanced)))
print("Mean PR_AUC: " + str(np.mean(pr_auc_balanced)))
# Out:
# Mean ROC-AUC: 0.7518112694595251
# Mean Accuracy: 0.723710646130607
# Mean PR_AUC: 0.17996602265290093

# %%
## check the annotation data
dat = pd.read_csv("20220131_all_paragraphs_2020_added_missings_added.csv")
not_aligned = pd.DataFrame(columns = dat.columns)
for id in annotated['speech_par_id']:
    if id in dat['speech_par_id'].tolist():
        if dat.loc[dat['speech_par_id']== id,'text'].values[0] != annotated.loc[annotated["speech_par_id"] == id, 'text'].values[0]:
            print(dat[dat['speech_par_id']== id])
            print(annotated[annotated["speech_par_id"] == id])
            not_aligned = not_aligned.append(dat[dat['speech_par_id']== id])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Unnamed: 0 Speech_id  \
# 36012       36013      1092
#
#                                                     text party    term   comp  \
# 36012  I don't know how thick your hide is.  But it's...   rep  1952.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 36012                 False      14       1092_14
#                                                  text  pred_class  \
# 38  I don't know how thick your hide is.  But it's...           0
#
#    speech_par_id speech_par_id_old
# 38       1092_14           1092_14
#        Unnamed: 0 Speech_id  \
# 25704       25705      1108
#
#                                                     text party    term  comp  \
# 25704  Mr. Chairman, ladies and gentlemen:  If I cann...   rep  1952.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 25704                 False       0        1108_0
#                                                  text  pred_class  \
# 45  Mr. Chairman, ladies and gentlemen:  If I cann...           0
#
#    speech_par_id            speech_par_id_old
# 45        1108_0  2008-09-25-new-york-city_18
#       Unnamed: 0 Speech_id                                               text  \
# 7063        7064      1170  Now, that is the kind of recommendation that i...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 7063   rep  1952.0  False                 False       2        1170_2
#                                                  text  pred_class  \
# 63  Now, that is the kind of recommendation that i...           0
#
#    speech_par_id speech_par_id_old
# 63        1170_2           2197_17
#        Unnamed: 0 Speech_id  \
# 42242       42243      1183
#
#                                                     text party    term   comp  \
# 42242  Ladies and gentlemen: there is not much relati...   rep  1952.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 42242                 False       0        1183_0
#                                                  text  pred_class  \
# 70  Ladies and gentlemen: there is not much relati...           0
#
#    speech_par_id speech_par_id_old
# 70        1183_0            1183_0
#        Unnamed: 0 Speech_id  \
# 40294       40295      1234
#
#                                                     text party    term  comp  \
# 40294  Governor Barrett, I see there are some people ...   rep  1952.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 40294                 False       0        1234_0
#                                                  text  pred_class  \
# 91  Governor Barrett, I see there are some people ...           0
#
#    speech_par_id speech_par_id_old
# 91        1234_0            1234_0
#        Unnamed: 0 Speech_id  \
# 30020       30021      1241
#
#                                                     text party    term   comp  \
# 30020  They fear, they say, that a new administration...   rep  1952.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 30020                 False       7        1241_7
#                                                  text  pred_class  \
# 95  They fear, they say, that a new administration...           0
#
#    speech_par_id speech_par_id_old
# 95        1241_7            1241_7
#        Unnamed: 0 Speech_id  \
# 29863       29864      1269
#
#                                                     text party    term  comp  \
# 29863  A strong America, a well-governed America, an ...   rep  1952.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 29863                  True      21       1269_21
#                                                   text  pred_class  \
# 101  A strong America, a well-governed America, an ...           0
#
#     speech_par_id speech_par_id_old
# 101       1269_21           2204_54
#        Unnamed: 0 Speech_id  \
# 28060       28061      1323
#
#                                                     text party    term   comp  \
# 28060  Fellow veterans, fellow Legionnaires. I can't ...   dem  1956.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 28060                 False       0        1323_0
#                                                   text  pred_class  \
# 133  Fellow veterans, fellow Legionnaires. I can't ...           0
#
#     speech_par_id speech_par_id_old
# 133        1323_0            1323_0
#        Unnamed: 0 Speech_id  \
# 38359       38360      1326
#
#                                                     text party    term  comp  \
# 38359  Even more is it true that our hopes for peace ...   dem  1956.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 38359                 False      13       1326_13
#                                                   text  pred_class  \
# 134  Even more is it true that our hopes for peace ...           0
#
#     speech_par_id speech_par_id_old
# 134       1326_13           2195_15
#        Unnamed: 0 Speech_id  \
# 42014       42015      1342
#
#                                                     text party    term  comp  \
# 42014  Yet only a few weeks later he made his unhappy...   dem  1956.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 42014                 False       3        1342_3
#                                                   text  pred_class  \
# 140  Yet only a few weeks later he made his unhappy...           0
#
#     speech_par_id                        speech_par_id_old
# 140        1342_3  2008-10-27-campaign-closing-argument_14
#        Unnamed: 0 Speech_id  \
# 45174       45175      1347
#
#                                                     text party    term  comp  \
# 45174  The magazines and newspapers, which denounce g...   dem  1956.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 45174                 False      21       1347_21
#                                                   text  pred_class  \
# 143  The magazines and newspapers, which denounce g...           0
#
#     speech_par_id speech_par_id_old
# 143       1347_21           1347_21
#        Unnamed: 0 Speech_id  \
# 38812       38813      1369
#
#                                                     text party    term  comp  \
# 38812  When there was a strike at the auto agency of ...   dem  1956.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 38812                 False       5        1369_5
#                                                   text  pred_class  \
# 156  When there was a strike at the auto agency of ...           0
#
#     speech_par_id              speech_par_id_old
# 156        1369_5  2004-10-18-tampa-florida-7_20
#        Unnamed: 0 Speech_id  \
# 41799       41800      1381
#
#                                                     text party    term  comp  \
# 41799  Yet the Republicans sneer and call it """"nons...   dem  1956.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 41799                 False      15       1381_15
#                                                   text  pred_class  \
# 166  Yet the Republicans sneer and call it ""nonsen...           0
#
#     speech_par_id speech_par_id_old
# 166       1381_15           1381_15
#        Unnamed: 0 Speech_id  \
# 48083       48084      1391
#
#                                                     text party    term  comp  \
# 48083  We in the Democratic party think there is noth...   dem  1956.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 48083                 False       5        1391_5
#                                                   text  pred_class  \
# 175  We in the Democratic party think there is noth...           0
#
#     speech_par_id speech_par_id_old
# 175        1391_5            1391_5
#       Unnamed: 0 Speech_id                                               text  \
# 9743        9744      1417  Yet in our labor toward the peace we seek, we ...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 9743   rep  1956.0  False                 False      24       1417_24
#                                                   text  pred_class  \
# 191  Yet in our labor toward the peace we seek, we ...           0
#
#     speech_par_id speech_par_id_old
# 191       1417_24           1417_24
#        Unnamed: 0 Speech_id  \
# 42053       42054      1424
#
#                                                     text party    term  comp  \
# 42053  Now, permit me two observations. First, I offe...   rep  1956.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 42053                  True       5        1424_5
#                                                   text  pred_class  \
# 192  Now, permit me two observations. First, I offe...           0
#
#     speech_par_id speech_par_id_old
# 192        1424_5            2952_9
#       Unnamed: 0 Speech_id                                               text  \
# 2236        2237      1605  The only war that would make less sense would ...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 2236   dem  1960.0  False                  True      16       1605_16
#                                                   text  pred_class  \
# 237  The only war that would make less sense would ...           0
#
#     speech_par_id speech_par_id_old
# 237       1605_16           1605_16
#        Unnamed: 0 Speech_id  \
# 39388       39389      1619
#
#                                                     text party    term  comp  \
# 39388  In 1860 when the choice was somewhat similar i...   dem  1960.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 39388                 False      15       1619_15
#                                                   text  pred_class  \
# 241  In 1860 when the choice was somewhat similar i...           1
#
#     speech_par_id speech_par_id_old
# 241       1619_15           1619_15
#        Unnamed: 0 Speech_id  \
# 45473       45474      1623
#
#                                                     text party    term  comp  \
# 45473  Quite obviously, if we don't solve it, if we d...   dem  1960.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 45473                 False       4        1623_4
#                                                   text  pred_class  \
# 242  Quite obviously, if we don't solve it, if we d...           0
#
#     speech_par_id speech_par_id_old
# 242        1623_4            1623_4
#        Unnamed: 0 Speech_id  \
# 35902       35903      1643
#
#                                                     text party    term   comp  \
# 35902  I believe that we can get at this matter very ...   dem  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 35902                 False      11       1643_11
#                                                   text  pred_class  \
# 249  I believe that we can get at this matter very ...           0
#
#     speech_par_id speech_par_id_old
# 249       1643_11           1643_11
#        Unnamed: 0 Speech_id  \
# 18174       18175      1665
#
#                                                     text party    term   comp  \
# 18174  Mr. Nixon and I have differed completely on th...   dem  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 18174                 False       4        1665_4
#                                                   text  pred_class  \
# 253  Mr. Nixon and I have differed completely on th...           0
#
#     speech_par_id speech_par_id_old
# 253        1665_4            1665_4
#        Unnamed: 0 Speech_id  \
# 21145       21146      1714
#
#                                                     text party    term   comp  \
# 21145  The Soviet Union is working night and day.  Th...   dem  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 21145                 False       7        1714_7
#                                                   text  pred_class  \
# 264  The Soviet Union is working night and day.  Th...           0
#
#     speech_par_id speech_par_id_old
# 264        1714_7            1714_7
#        Unnamed: 0 Speech_id  \
# 29537       29538      1725
#
#                                                     text party    term   comp  \
# 29537  This campaign is coming to an end Tuesday nigh...   dem  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 29537                  True       1        1725_1
#                                                   text  pred_class  \
# 267  This campaign is coming to an end Tuesday nigh...           0
#
#     speech_par_id speech_par_id_old
# 267        1725_1            1725_1
#        Unnamed: 0 Speech_id  \
# 45941       45942      1757
#
#                                                     text party    term   comp  \
# 45941  I think it's one of the primary responsibiliti...   rep  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 45941                 False      10       1757_10
#                                                   text  pred_class  \
# 280  I think it's one of the primary responsibiliti...           0
#
#     speech_par_id speech_par_id_old
# 280       1757_10           1757_10
#      Unnamed: 0 Speech_id                                               text  \
# 901         902      1764  So, for these two reasons, the President was r...
#
#     party    term  comp populist_old_keywords  par_id speech_par_id
# 901   rep  1960.0  True                 False      13       1764_13
#                                                   text  pred_class  \
# 283  So, for these two reasons, the President was r...           0
#
#     speech_par_id speech_par_id_old
# 283       1764_13           1764_13
#       Unnamed: 0 Speech_id                                               text  \
# 5173        5174      1766  What should our attitude be in the first place...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 5173   rep  1960.0  False                 False       6        1766_6
#                                                   text  pred_class  \
# 288  What should our attitude be in the first place...           0
#
#     speech_par_id                speech_par_id_old
# 288        1766_6  2012-10-01-denver-colorado-0_29
#        Unnamed: 0 Speech_id  \
# 11657       11658      1774
#
#                                                     text party    term   comp  \
# 11657  While I am speaking on this subject, may I jus...   rep  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 11657                 False      26       1774_26
#                                                   text  pred_class  \
# 294  While I am speaking on this subject, may I jus...           0
#
#     speech_par_id speech_par_id_old
# 294       1774_26           1774_26
#       Unnamed: 0 Speech_id                                               text  \
# 9030        9031      1818  So, you've got to think of that.  If you want ...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 9030   rep  1960.0  False                  True       8        1818_8
#                                                   text  pred_class  \
# 327  So, you've got to think of that.  If you want ...           0
#
#     speech_par_id speech_par_id_old
# 327        1818_8           3116_23
#        Unnamed: 0 Speech_id  \
# 25628       25629      1849
#
#                                                     text party    term   comp  \
# 25628  And also I say this: when all that our opponen...   rep  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 25628                 False       3        1849_3
#                                                   text  pred_class  \
# 342  And also I say this: when all that our opponen...           0
#
#     speech_par_id speech_par_id_old
# 342        1849_3            1849_3
#        Unnamed: 0 Speech_id  \
# 28009       28010      1860
#
#                                                     text party    term   comp  \
# 28009  All these things sound so far away sometimes, ...   rep  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 28009                 False      15       1860_15
#                                                   text  pred_class  \
# 352  All these things sound so far away sometimes, ...           0
#
#     speech_par_id speech_par_id_old
# 352       1860_15           1860_15
#        Unnamed: 0 Speech_id  \
# 35773       35774      1870
#
#                                                     text party    term   comp  \
# 35773  So, here are three instances where he first sa...   rep  1960.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 35773                 False      34       1870_34
#                                                   text  pred_class  \
# 359  So, here are three instances where he first sa...           0
#
#     speech_par_id speech_par_id_old
# 359       1870_34           3299_38
#        Unnamed: 0 Speech_id  \
# 37951       37952      1871
#
#                                                     text party    term  comp  \
# 37951  But, getting back to the issues before us, I s...   rep  1960.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 37951                 False       3        1871_3
#                                                   text  pred_class  \
# 361  But, getting back to the issues before us, I s...           0
#
#     speech_par_id speech_par_id_old
# 361        1871_3            1871_3
#        Unnamed: 0 Speech_id  \
# 34005       34006      1906
#
#                                                     text party    term   comp  \
# 34005  The statue atop the State House of Rhode Islan...   dem  1964.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 34005                 False      16       1906_16
#                                                   text  pred_class  \
# 384  The statue atop the State House of Rhode Islan...           1
#
#     speech_par_id speech_par_id_old
# 384       1906_16           1906_16
#        Unnamed: 0 Speech_id  \
# 32675       32676      1907
#
#                                                     text party    term   comp  \
# 32675  For 175 years, through more than forty nationa...   dem  1964.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 32675                  True      16       1907_16
#                                                   text  pred_class  \
# 386  For 175 years, through more than forty nationa...           0
#
#     speech_par_id speech_par_id_old
# 386       1907_16           1907_16
#        Unnamed: 0 Speech_id  \
# 13731       13732      1908
#
#                                                     text party    term  comp  \
# 13731  """"So that is the first reason I came."""" An...   dem  1964.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 13731                 False      26       1908_26
#                                                   text  pred_class  \
# 388  ""So that is the first reason I came."" And he...           0
#
#     speech_par_id speech_par_id_old
# 388       1908_26           1908_26
#        Unnamed: 0 Speech_id  \
# 37530       37531      1911
#
#                                                     text party    term  comp  \
# 37530  From Portland, Oregon, he was asked, """"How c...   dem  1964.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 37530                 False       3        1911_3
#                                                   text  pred_class  \
# 391  From Portland, Oregon, he was asked, ""How can...           0
#
#     speech_par_id speech_par_id_old
# 391        1911_3            1911_3
#        Unnamed: 0 Speech_id  \
# 37532       37533      1911
#
#                                                     text party    term   comp  \
# 37532  Everyone agreed on the great shaping principle...   dem  1964.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 37532                 False       5        1911_5
#                                                   text  pred_class  \
# 392  Everyone agreed on the great shaping principle...           0
#
#     speech_par_id speech_par_id_old
# 392        1911_5            1911_5
#        Unnamed: 0 Speech_id  \
# 23005       23006      1925
#
#                                                     text party    term  comp  \
# 23005  Not long ago, a dictator, Mr. Castro, cut our ...   dem  1964.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 23005                 False      16       1925_16
#                                                   text  pred_class  \
# 397  Not long ago, a dictator, Mr. Castro, cut our ...           0
#
#     speech_par_id speech_par_id_old
# 397       1925_16           1925_16
#        Unnamed: 0 Speech_id  \
# 27615       27616      1928
#
#                                                     text party    term  comp  \
# 27615  Old man James said, """"Well, Sammy, if that's...   dem  1964.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 27615                 False      43       1928_43
#                                                   text  pred_class  \
# 402  Old man James said, ""Well, Sammy, if that's t...           0
#
#     speech_par_id speech_par_id_old
# 402       1928_43            1994_9
#        Unnamed: 0 Speech_id  \
# 35988       35989      1938
#
#                                                     text party    term   comp  \
# 35988  So you have three weeks now to decide. You wil...   dem  1964.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 35988                 False      28       1938_28
#                                                   text  pred_class  \
# 412  So you have three weeks now to decide. You wil...           0
#
#     speech_par_id speech_par_id_old
# 412       1938_28           1938_28
#        Unnamed: 0 Speech_id  \
# 10291       10292      1946
#
#                                                     text party    term   comp  \
# 10291  I was talking to some folks coming up on the p...   dem  1964.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 10291                 False       6        1946_6
#                                                   text  pred_class  \
# 417  I was talking to some folks coming up on the p...           0
#
#     speech_par_id speech_par_id_old
# 417        1946_6            1946_6
#       Unnamed: 0 Speech_id                                               text  \
# 2156        2157      1956  He had a vision of a world at peace. """"We wi...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 2156   dem  1964.0  False                 False       1        1956_1
#                                                   text  pred_class  \
# 422  He had a vision of a world at peace. ""We will...           0
#
#     speech_par_id speech_par_id_old
# 422        1956_1            1956_1
#        Unnamed: 0 Speech_id  \
# 50388       50389      1966
#
#                                                     text party    term   comp  \
# 50388  I don't think there is but one real issue in t...   dem  1964.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 50388                 False       8        1966_8
#                                                   text  pred_class  \
# 426  I don't think there is but one real issue in t...           0
#
#     speech_par_id                          speech_par_id_old
# 426        1966_8  2008-10-28-remarks-chester-pennsylvania_7
#       Unnamed: 0 Speech_id                                               text  \
# 3969        3970      1968  The boy said, """"Well, I listened to a United...
#
#      party    term  comp populist_old_keywords  par_id speech_par_id
# 3969   dem  1964.0  True                 False      21       1968_21
#                                                   text  pred_class  \
# 427  The boy said, ""Well, I listened to a United S...           0
#
#     speech_par_id                speech_par_id_old
# 427       1968_21  2004-10-31-cincinnati-ohio-1_55
#       Unnamed: 0 Speech_id                                               text  \
# 8289        8290      1987  Let's don't try to threaten people by ultimatu...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 8289   dem  1964.0  False                 False      31       1987_31
#                                                   text  pred_class  \
# 446  Let's don't try to threaten people by ultimatu...           0
#
#     speech_par_id speech_par_id_old
# 446       1987_31           1987_31
#        Unnamed: 0                               Speech_id  \
# 59756       59757  2004-09-09-remarks-colmar-pennsylvania
#
#                                                     text party    term   comp  \
# 59756  Eunice Sanchez is with us. Where are you, Euni...   rep  2004.0  False
#
#       populist_old_keywords  par_id                              speech_par_id
# 59756                 False      13  2004-09-09-remarks-colmar-pennsylvania_13
#                                                   text  pred_class  \
# 512  Eunice Sanchez is with us. Where are you, Euni...           0
#
#                                  speech_par_id  \
# 512  2004-09-09-remarks-colmar-pennsylvania_13
#
#                              speech_par_id_old
# 512  2004-09-09-remarks-colmar-pennsylvania_13
#        Unnamed: 0                              Speech_id  \
# 58171       58172  2004-09-10-discussion-portsmouth-ohio
#
#                                                     text party    term   comp  \
# 58171  A free Afghanistan will help us keep the peace...   rep  2004.0  False
#
#       populist_old_keywords  par_id                              speech_par_id
# 58171                 False     109  2004-09-10-discussion-portsmouth-ohio_109
#                                                   text  pred_class  \
# 524  A free Afghanistan will help us keep the peace...           0
#
#                                  speech_par_id speech_par_id_old
# 524  2004-09-10-discussion-portsmouth-ohio_109           3320_24
#        Unnamed: 0                          Speech_id  \
# 59708       59709  2004-09-17-victory-2004-reception
#
#                                                     text party    term   comp  \
# 59708  And secondly, we've heard the rhetoric before,...   rep  2004.0  False
#
#       populist_old_keywords  par_id                         speech_par_id
# 59708                  True      21  2004-09-17-victory-2004-reception_21
#                                                   text  pred_class  \
# 540  And secondly, we've heard the rhetoric before,...           0
#
#                             speech_par_id speech_par_id_old
# 540  2004-09-17-victory-2004-reception_21            1853_7
#        Unnamed: 0                             Speech_id  \
# 61378       61379  2004-09-22-king-prussia-pennsylvania
#
#                                                     text party    term   comp  \
# 61378  You want this economy to continue to grow, we'...   rep  2004.0  False
#
#       populist_old_keywords  par_id                            speech_par_id
# 61378                  True      21  2004-09-22-king-prussia-pennsylvania_21
#                                                   text  pred_class  \
# 549  You want this economy to continue to grow, we'...           0
#
#                                speech_par_id  \
# 549  2004-09-22-king-prussia-pennsylvania_21
#
#                      speech_par_id_old
# 549  2004-09-08-center-miami-florida_1
#        Unnamed: 0                              Speech_id  \
# 65217       65218  2004-09-27-education-springfield-ohio
#
#                                                     text party    term   comp  \
# 65217  In a different kind of war, we had to recogniz...   rep  2004.0  False
#
#       populist_old_keywords  par_id                             speech_par_id
# 65217                 False      81  2004-09-27-education-springfield-ohio_81
#                                                   text  pred_class  \
# 571  In a different kind of war, we had to recogniz...           0
#
#                                 speech_par_id  \
# 571  2004-09-27-education-springfield-ohio_81
#
#                             speech_par_id_old
# 571  2004-09-27-education-springfield-ohio_81
#        Unnamed: 0                         Speech_id  \
# 59199       59200  2004-10-04-discussion-clive-iowa
#
#                                                     text party    term   comp  \
# 59199  See, you'll hear some talk about, you know, re...   rep  2004.0  False
#
#       populist_old_keywords  par_id                        speech_par_id
# 59199                 False      37  2004-10-04-discussion-clive-iowa_37
#                                                   text  pred_class  \
# 589  See, you'll hear some talk about, you know, re...           0
#
#                            speech_par_id                    speech_par_id_old
# 589  2004-10-04-discussion-clive-iowa_37  2004-10-04-discussion-clive-iowa_37
#        Unnamed: 0                    Speech_id  \
# 71415       71416  2004-10-14-people-las-vegas
#
#                                                     text party    term   comp  \
# 71415  And so, I say to you, Mr. President: after fou...   dem  2004.0  False
#
#       populist_old_keywords  par_id                   speech_par_id
# 71415                 False      13  2004-10-14-people-las-vegas_13
#                                                   text  pred_class  \
# 615  And so, I say to you, Mr. President: after fou...           0
#
#                       speech_par_id                   speech_par_id_old
# 615  2004-10-14-people-las-vegas_13  2004-10-19-petersburg-florida-0_60
#        Unnamed: 0                      Speech_id  \
# 60507       60508  2004-10-18-marlton-new-jersey
#
#                                                     text party    term   comp  \
# 60507  My opponent has a fundamental misunderstanding...   rep  2004.0  False
#
#       populist_old_keywords  par_id                     speech_par_id
# 60507                 False      28  2004-10-18-marlton-new-jersey_28
#                                                   text  pred_class  \
# 628  My opponent has a fundamental misunderstanding...           0
#
#                         speech_par_id                 speech_par_id_old
# 628  2004-10-18-marlton-new-jersey_28  2004-10-18-marlton-new-jersey_28
#        Unnamed: 0                        Speech_id  \
# 62493       62494  2004-10-19-petersburg-florida-0
#
#                                                     text party    term   comp  \
# 62493  The President. These lawsuits drive up insuran...   rep  2004.0  False
#
#       populist_old_keywords  par_id                       speech_par_id
# 62493                 False      35  2004-10-19-petersburg-florida-0_35
#                                                   text  pred_class  \
# 633  The President. These lawsuits drive up insuran...           0
#
#                           speech_par_id speech_par_id_old
# 633  2004-10-19-petersburg-florida-0_35           2745_42
#        Unnamed: 0                       Speech_id  \
# 62389       62390  2004-10-19-port-richey-florida
#
#                                                     text party    term  comp  \
# 62389  Audience members. But he can't hide! The Presi...   rep  2004.0  True
#
#       populist_old_keywords  par_id                      speech_par_id
# 62389                 False      58  2004-10-19-port-richey-florida_58
#                                                   text  pred_class  \
# 639  Audience members. But he can't hide! The Presi...           0
#
#                          speech_par_id                  speech_par_id_old
# 639  2004-10-19-port-richey-florida_58  2004-10-19-port-richey-florida_58
#        Unnamed: 0                        Speech_id  \
# 60740       60741  2004-10-19-the-villages-florida
#
#                                                     text party    term   comp  \
# 60740  The President. He dismisses it as simply a lab...   rep  2004.0  False
#
#       populist_old_keywords  par_id                       speech_par_id
# 60740                 False      34  2004-10-19-the-villages-florida_34
#                                                   text  pred_class  \
# 641  The President. He dismisses it as simply a lab...           0
#
#                           speech_par_id                    speech_par_id_old
# 641  2004-10-19-the-villages-florida_34  2012-10-19-daytona-beach-florida_21
#        Unnamed: 0                        Speech_id  \
# 61529       61530  2004-10-20-eau-claire-wisconsin
#
#                                                     text party    term   comp  \
# 61529  I signed a good farm bill which is helping the...   rep  2004.0  False
#
#       populist_old_keywords  par_id                       speech_par_id
# 61529                  True      12  2004-10-20-eau-claire-wisconsin_12
#                                                   text  pred_class  \
# 644  I signed a good farm bill which is helping the...           0
#
#                           speech_par_id                     speech_par_id_old
# 644  2004-10-20-eau-claire-wisconsin_12  2004-11-02-reporters-columbus-ohio_3
#        Unnamed: 0                             Speech_id  \
# 62640       62641  2004-10-23-remarks-melbourne-florida
#
#                                                     text party    term   comp  \
# 62640  Every election, desperate politicians try to s...   rep  2004.0  False
#
#       populist_old_keywords  par_id                            speech_par_id
# 62640                 False      48  2004-10-23-remarks-melbourne-florida_48
#                                                   text  pred_class  \
# 670  Every election, desperate politicians try to s...           0
#
#                                speech_par_id  \
# 670  2004-10-23-remarks-melbourne-florida_48
#
#                            speech_par_id_old
# 670  2004-10-23-remarks-melbourne-florida_48
#        Unnamed: 0                            Speech_id  \
# 58331       58332  2004-10-25-remarks-greeley-colorado
#
#                                                     text party    term  comp  \
# 58331  Since then, the Senator has said the whole mat...   rep  2004.0  True
#
#       populist_old_keywords  par_id                           speech_par_id
# 58331                 False      62  2004-10-25-remarks-greeley-colorado_62
#                                                   text  pred_class  \
# 683  Since then, the Senator has said the whole mat...           0
#
#                               speech_par_id  \
# 683  2004-10-25-remarks-greeley-colorado_62
#
#                           speech_par_id_old
# 683  2004-10-25-remarks-greeley-colorado_62
#        Unnamed: 0                      Speech_id  \
# 60030       60031  2004-10-28-saginaw-michigan-0
#
#                                                     text party    term   comp  \
# 60030  Several times during the course of this campai...   rep  2004.0  False
#
#       populist_old_keywords  par_id                     speech_par_id
# 60030                 False      22  2004-10-28-saginaw-michigan-0_22
#                                                   text  pred_class  \
# 712  Several times during the course of this campai...           0
#
#                         speech_par_id                 speech_par_id_old
# 712  2004-10-28-saginaw-michigan-0_22  2004-10-28-saginaw-michigan-0_22
#        Unnamed: 0                      Speech_id  \
# 60054       60055  2004-10-28-saginaw-michigan-0
#
#                                                     text party    term   comp  \
# 60054  When I ran—when I was running for President 4 ...   rep  2004.0  False
#
#       populist_old_keywords  par_id                     speech_par_id
# 60054                  True      47  2004-10-28-saginaw-michigan-0_47
#                                                   text  pred_class  \
# 713  When I ran—when I was running for President 4 ...           0
#
#                         speech_par_id                 speech_par_id_old
# 713  2004-10-28-saginaw-michigan-0_47  2004-10-28-saginaw-michigan-0_47
#        Unnamed: 0                         Speech_id  \
# 63391       63392  2004-10-30-grand-rapids-michigan
#
#                                                     text party    term   comp  \
# 63391  And here's something you need to be wary about...   rep  2004.0  False
#
#       populist_old_keywords  par_id                        speech_par_id
# 63391                 False      45  2004-10-30-grand-rapids-michigan_45
#                                                   text  pred_class  \
# 720  And here's something you need to be wary about...           0
#
#                            speech_par_id speech_par_id_old
# 720  2004-10-30-grand-rapids-michigan_45           2724_13
#        Unnamed: 0               Speech_id  \
# 58694       58695  2004-11-01-city-iowa-0
#
#                                                     text party    term   comp  \
# 58694  He's given several explanations of that vote s...   rep  2004.0  False
#
#       populist_old_keywords  par_id              speech_par_id
# 58694                 False      35  2004-11-01-city-iowa-0_35
#                                                   text  pred_class  \
# 729  He's given several explanations of that vote s...           0
#
#                  speech_par_id speech_par_id_old
# 729  2004-11-01-city-iowa-0_35           1619_14
#        Unnamed: 0                  Speech_id  \
# 59681       59682  2004-11-01-dallas-texas-1
#
#                                                     text party    term  comp  \
# 59681  He has given a lot of explanations about that ...   rep  2004.0  True
#
#       populist_old_keywords  par_id                 speech_par_id
# 59681                 False      24  2004-11-01-dallas-texas-1_24
#                                                   text  pred_class  \
# 733  He has given a lot of explanations about that ...           0
#
#                     speech_par_id speech_par_id_old
# 733  2004-11-01-dallas-texas-1_24            2840_1
#        Unnamed: 0                           Speech_id  \
# 58786       58787  2004-11-01-remarks-wilmington-ohio
#
#                                                     text party    term   comp  \
# 58786  My opponent has got an economic plan. He's bee...   rep  2004.0  False
#
#       populist_old_keywords  par_id                          speech_par_id
# 58786                 False      14  2004-11-01-remarks-wilmington-ohio_14
#                                                   text  pred_class  \
# 739  My opponent has got an economic plan. He's bee...           0
#
#                              speech_par_id speech_par_id_old
# 739  2004-11-01-remarks-wilmington-ohio_14           1127_31
#        Unnamed: 0                           Speech_id  \
# 66439       66440  2008-10-22-goffstown-new-hampshire
#
#                                                     text party    term   comp  \
# 66439  In other words, Joe and guys like him will ear...   rep  2008.0  False
#
#       populist_old_keywords  par_id                         speech_par_id
# 66439                 False       4  2008-10-22-goffstown-new-hampshire_4
#                                                   text  pred_class  \
# 802  In other words, Joe and guys like him will ear...           0
#
#                             speech_par_id  \
# 802  2008-10-22-goffstown-new-hampshire_4
#
#                         speech_par_id_old
# 802  2008-10-22-goffstown-new-hampshire_4
#        Unnamed: 0                          Speech_id  \
# 52552       52553  2008-10-29-raleigh-north-carolina
#
#                                                     text party    term   comp  \
# 52552  That's his choice. That's the kind of campaign...   dem  2008.0  False
#
#       populist_old_keywords  par_id                         speech_par_id
# 52552                 False      12  2008-10-29-raleigh-north-carolina_12
#                                                   text  pred_class  \
# 812  That's his choice. That's the kind of campaign...           0
#
#                             speech_par_id speech_par_id_old
# 812  2008-10-29-raleigh-north-carolina_12           3324_45
#        Unnamed: 0                            Speech_id  \
# 53662       53663  2012-09-07-portsmouth-new-hampshire
#
#                                                     text party    term   comp  \
# 53662  Fourth, fourth, my plan would reduce our defic...   dem  2012.0  False
#
#       populist_old_keywords  par_id                           speech_par_id
# 53662                 False      36  2012-09-07-portsmouth-new-hampshire_36
#                                                   text  pred_class  \
# 844  Fourth, fourth, my plan would reduce our defic...           0
#
#                               speech_par_id  \
# 844  2012-09-07-portsmouth-new-hampshire_36
#
#                         speech_par_id_old
# 844  2012-10-07-los-angeles-california_21
#        Unnamed: 0                      Speech_id  \
# 53225       53226  2012-09-26-bowling-green-ohio
#
#                                                     text party    term   comp  \
# 53225  My opponent has got a different view. He said ...   dem  2012.0  False
#
#       populist_old_keywords  par_id                     speech_par_id
# 53225                 False      42  2012-09-26-bowling-green-ohio_42
#                                                   text  pred_class  \
# 885  My opponent has got a different view. He said ...           0
#
#                         speech_par_id                 speech_par_id_old
# 885  2012-09-26-bowling-green-ohio_42  2012-09-26-bowling-green-ohio_42
#        Unnamed: 0                      Speech_id  \
# 53231       53232  2012-09-26-bowling-green-ohio
#
#                                                     text party    term  comp  \
# 53231  You're the reason a young immigrant who grew u...   dem  2012.0  True
#
#       populist_old_keywords  par_id                     speech_par_id
# 53231                 False      48  2012-09-26-bowling-green-ohio_48
#                                                   text  pred_class  \
# 886  You're the reason a young immigrant who grew u...           1
#
#                         speech_par_id                 speech_par_id_old
# 886  2012-09-26-bowling-green-ohio_48  2012-09-26-bowling-green-ohio_48
#        Unnamed: 0                          Speech_id  \
# 57783       57784  2012-09-26-event-westerville-ohio
#
#                                                     text party    term   comp  \
# 57783  Every now and then I — I see protesters now an...   rep  2012.0  False
#
#       populist_old_keywords  par_id                         speech_par_id
# 57783                 False      10  2012-09-26-event-westerville-ohio_10
#                                                   text  pred_class  \
# 890  Every now and then I — I see protesters now an...           0
#
#                             speech_par_id  \
# 890  2012-09-26-event-westerville-ohio_10
#
#                         speech_par_id_old
# 890  2012-09-26-event-westerville-ohio_10
#        Unnamed: 0                         Speech_id  \
# 57501       57502  2012-10-05-st-petersburg-florida
#
#                                                     text party    term  comp  \
# 57501  I asked him, for instance, why with 23 million...   rep  2012.0  True
#
#       populist_old_keywords  par_id                       speech_par_id
# 57501                 False       7  2012-10-05-st-petersburg-florida_7
#                                                   text  pred_class  \
# 916  I asked him, for instance, why with 23 million...           0
#
#                           speech_par_id                    speech_par_id_old
# 916  2012-10-05-st-petersburg-florida_7  2016-10-25-coconut-creek-florida_39
#        Unnamed: 0                        Speech_id  \
# 56826       56827  2012-10-09-event-cuyahoga-falls
#
#                                                     text party    term   comp  \
# 56826  And number five — and number five, we're going...   rep  2012.0  False
#
#       populist_old_keywords  par_id                       speech_par_id
# 56826                 False      31  2012-10-09-event-cuyahoga-falls_31
#                                                   text  pred_class  \
# 930  And number five — and number five, we're going...           0
#
#                           speech_par_id                   speech_par_id_old
# 930  2012-10-09-event-cuyahoga-falls_31  2012-10-09-event-cuyahoga-falls_31
#        Unnamed: 0                           Speech_id  \
# 56705       56706  2012-10-17-rally-leesburg-virginia
#
#                                                     text party    term   comp  \
# 56705  The president was asked a number of times abou...   rep  2012.0  False
#
#       populist_old_keywords  par_id                          speech_par_id
# 56705                 False      20  2012-10-17-rally-leesburg-virginia_20
#                                                   text  pred_class  \
# 944  The president was asked a number of times abou...           0
#
#                              speech_par_id speech_par_id_old
# 944  2012-10-17-rally-leesburg-virginia_20           2040_23
#        Unnamed: 0                            Speech_id  \
# 55681       55682  2012-10-18-manchester-new-hampshire
#
#                                                     text party    term   comp  \
# 55681  You're the reason folks who served us so brave...   dem  2012.0  False
#
#       populist_old_keywords  par_id                           speech_par_id
# 55681                 False      67  2012-10-18-manchester-new-hampshire_67
#                                                   text  pred_class  \
# 945  You're the reason folks who served us so brave...           0
#
#                               speech_par_id  \
# 945  2012-10-18-manchester-new-hampshire_67
#
#                       speech_par_id_old
# 945  2004-09-07-lees-summit-missouri_12
#        Unnamed: 0                        Speech_id  \
# 54479       54480  2012-10-25-rally-cleveland-ohio
#
#                                                     text party    term   comp  \
# 54479  I don't want fuel-efficient cars or long-lasti...   dem  2012.0  False
#
#       populist_old_keywords  par_id                       speech_par_id
# 54479                 False      35  2012-10-25-rally-cleveland-ohio_35
#                                                   text  pred_class  \
# 959  I don't want fuel-efficient cars or long-lasti...           0
#
#                           speech_par_id speech_par_id_old
# 959  2012-10-25-rally-cleveland-ohio_35            1910_3
#        Unnamed: 0                   Speech_id  \
# 53973       53974  2012-11-02-rally-lima-ohio
#
#                                                     text party    term   comp  \
# 53973  Today, there are thousands of workers here in ...   dem  2012.0  False
#
#       populist_old_keywords  par_id                  speech_par_id
# 53973                 False      28  2012-11-02-rally-lima-ohio_28
#                                                   text  pred_class  \
# 976  Today, there are thousands of workers here in ...           0
#
#                      speech_par_id              speech_par_id_old
# 976  2012-11-02-rally-lima-ohio_28  2012-11-02-rally-lima-ohio_28
#        Unnamed: 0                       Speech_id  \
# 51369       51370  2012-11-05-rally-columbus-ohio
#
#                                                     text party    term   comp  \
# 51369  And that is not a partisan statement. When the...   dem  2012.0  False
#
# ...
#        Unnamed: 0 Speech_id  \
# 30499       30500      2952
#
#                                                     text party    term  comp  \
# 30499  Deep differences on values--my opponent vetoed...   rep  1988.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 30499                 False       9        2952_9
#                                                    text  pred_class  \
# 1756  Deep differences on values--my opponent vetoed...           0
#
#      speech_par_id                       speech_par_id_old
# 1756        2952_9  2016-10-12-state-fairgrounds-pueblo_23
#        Unnamed: 0 Speech_id  \
# 14794       14795      2964
#
#                                                     text party    term   comp  \
# 14794  A reporter at one of the radio networks called...   rep  1988.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 14794                 False       7        2964_7
#                                                    text  pred_class  \
# 1762  A reporter at one of the radio networks called...           0
#
#      speech_par_id speech_par_id_old
# 1762        2964_7            2964_7
#        Unnamed: 0 Speech_id  \
# 14833       14834      2970
#
#                                                     text party    term  comp  \
# 14833  His talk of statistics makes the victim even m...   rep  1988.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 14833                 False      19       2970_19
#                                                    text  pred_class  \
# 1769  His talk of statistics makes the victim even m...           0
#
#      speech_par_id speech_par_id_old
# 1769       2970_19           2970_19
#        Unnamed: 0 Speech_id  \
# 23896       23897      2975
#
#                                                     text party    term   comp  \
# 23896  In the course of this campaign, I have declare...   rep  1988.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 23896                 False      30       2975_30
#                                                    text  pred_class  \
# 1772  In the course of this campaign, I have declare...           0
#
#      speech_par_id speech_par_id_old
# 1772       2975_30           2975_30
#        Unnamed: 0 Speech_id  \
# 26271       26272      2978
#
#                                                     text party    term  comp  \
# 26271  Today, the """"middle class squeeze"""" has a ...   rep  1988.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 26271                 False      15       2978_15
#                                                    text  pred_class  \
# 1776  Today, the ""middle class squeeze"" has a diff...           0
#
#      speech_par_id speech_par_id_old
# 1776       2978_15           2829_33
#        Unnamed: 0 Speech_id  \
# 26260       26261      2978
#
#                                                     text party    term  comp  \
# 26260  Today, when you strip away all the rhetoric, a...   rep  1988.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 26260                 False       4        2978_4
#                                                    text  pred_class  \
# 1777  Today, when you strip away all the rhetoric, a...           0
#
#      speech_par_id speech_par_id_old
# 1777        2978_4            2978_4
#        Unnamed: 0 Speech_id  \
# 37035       37036      2997
#
#                                                     text party    term  comp  \
# 37035  I know that all of you here at Notre Dame will...   dem  1992.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 37035                  True      13       2997_13
#                                                    text  pred_class  \
# 1800  I know that all of you here at Notre Dame will...           1
#
#      speech_par_id                    speech_par_id_old
# 1800       2997_13  2012-10-23-event-henderson-nevada_9
#        Unnamed: 0 Speech_id  \
# 35812       35813      3040
#
#                                                     text party    term   comp  \
# 35812  My fellow Americans, I do not seek a victory o...   dem  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 35812                 False      14       3040_14
#                                                    text  pred_class  \
# 1838  My fellow Americans, I do not seek a victory o...           0
#
#      speech_par_id speech_par_id_old
# 1838       3040_14           3040_14
#        Unnamed: 0 Speech_id  \
# 32455       32456      3043
#
#                                                     text party    term  comp  \
# 32455  SENATOR HARKIN. Not then. GOVERNOR CLINTON. We...   dem  1992.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 32455                 False      19       3043_19
#                                                    text  pred_class  \
# 1842  SENATOR HARKIN. Not then. GOVERNOR CLINTON. We...           0
#
#      speech_par_id speech_par_id_old
# 1842       3043_19           3043_19
#        Unnamed: 0 Speech_id  \
# 30876       30877      3047
#
#                                                     text party    term   comp  \
# 30876  I want to say in the beginning, thanks to the ...   dem  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 30876                 False       2        3047_2
#                                                    text  pred_class  \
# 1844  I want to say in the beginning, thanks to the ...           0
#
#      speech_par_id                         speech_par_id_old
# 1844        3047_2  2016-08-09-north-carolina-wilmington_131
#        Unnamed: 0 Speech_id  \
# 13490       13491      3064
#
#                                                     text party    term   comp  \
# 13490  We tried this once before, combining the Democ...   rep  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 13490                 False      62       3064_62
#                                                    text  pred_class  \
# 1867  We tried this once before, combining the Democ...           0
#
#      speech_par_id speech_par_id_old
# 1867       3064_62           1367_14
#        Unnamed: 0 Speech_id  \
# 18163       18164      3072
#
#                                                     text party    term   comp  \
# 18163  Let me also say, one of the things we've got t...   rep  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 18163                 False       1        3072_1
#                                                    text  pred_class  \
# 1872  Let me also say, one of the things we've got t...           0
#
#      speech_par_id speech_par_id_old
# 1872        3072_1            3072_1
#        Unnamed: 0 Speech_id  \
# 38121       38122      3082
#
#                                                     text party    term  comp  \
# 38121  I used to say that the system would give us th...   rep  1992.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 38121                 False      22       3082_22
#                                                    text  pred_class  \
# 1884  I used to say that the system would give us th...           0
#
#      speech_par_id speech_par_id_old
# 1884       3082_22           3082_22
#        Unnamed: 0 Speech_id  \
# 38126       38127      3082
#
#                                                     text party    term   comp  \
# 38126  For now, at least, my opponent's chosen a very...   rep  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 38126                 False      27       3082_27
#                                                    text  pred_class  \
# 1885  For now, at least, my opponent's chosen a very...           0
#
#      speech_par_id speech_par_id_old
# 1885       3082_27           3082_27
#        Unnamed: 0 Speech_id  \
# 35735       35736      3097
#
#                                                     text party    term   comp  \
# 35735  You know, Bill Clinton talks a very good game....   rep  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 35735                 False      16       3097_16
#                                                    text  pred_class  \
# 1894  You know, Bill Clinton talks a very good game....           0
#
#      speech_par_id speech_par_id_old
# 1894       3097_16           3097_16
#        Unnamed: 0 Speech_id  \
# 49099       49100      3143
#
#                                                     text party    term   comp  \
# 49099  I have laid out this agenda for America's rene...   rep  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 49099                 False       9        3143_9
#                                                    text  pred_class  \
# 1920  I have laid out this agenda for America's rene...           0
#
#      speech_par_id speech_par_id_old
# 1920        3143_9            3143_9
#        Unnamed: 0 Speech_id  \
# 50263       50264      3156
#
#                                                     text party    term   comp  \
# 50263  Governor Clinton is talking about """"Well, we...   rep  1992.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 50263                 False      11       3156_11
#                                                    text  pred_class  \
# 1921  Governor Clinton is talking about ""Well, we r...           0
#
#      speech_par_id speech_par_id_old
# 1921       3156_11           3156_11
#       Unnamed: 0 Speech_id                                               text  \
# 5339        5340      3159  I think the colonel would have approved of our...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 5339   rep  1992.0  False                 False       5        3159_5
#                                                    text  pred_class  \
# 1923  I think the colonel would have approved of our...           0
#
#      speech_par_id speech_par_id_old
# 1923        3159_5           2642_19
#       Unnamed: 0 Speech_id                                               text  \
# 7325        7326      3161  Since I first sent that bill to the Hill in 19...
#
#      party    term   comp populist_old_keywords  par_id speech_par_id
# 7325   rep  1992.0  False                 False      11       3161_11
#                                                    text  pred_class  \
# 1925  Since I first sent that bill to the Hill in 19...           0
#
#      speech_par_id speech_par_id_old
# 1925       3161_11           3161_11
#       Unnamed: 0 Speech_id                                               text  \
# 4271        4272      3170  Two members of the family are with me, my daug...
#
#      party    term  comp populist_old_keywords  par_id speech_par_id
# 4271   rep  1992.0  True                 False       3        3170_3
#                                                    text  pred_class  \
# 1936  Two members of the family are with me, my daug...           0
#
#      speech_par_id speech_par_id_old
# 1936        3170_3            3170_3
#        Unnamed: 0 Speech_id  \
# 13113       13114      3272
#
#                                                     text party    term  comp  \
# 13113  When we were fighting for the battle over affi...   dem  1996.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 13113                 False      10       3272_10
#                                                    text  pred_class  \
# 2041  When we were fighting for the battle over affi...           1
#
#      speech_par_id speech_par_id_old
# 2041       3272_10           3272_10
#        Unnamed: 0 Speech_id  \
# 29732       29733      3318
#
#                                                     text party    term  comp  \
# 29732  It would have created fifty brand-new federal ...   rep  1996.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 29732                 False      16       3318_16
#                                                    text  pred_class  \
# 2096  It would have created fifty brand-new federal ...           0
#
#      speech_par_id speech_par_id_old
# 2096       3318_16           3318_16
#        Unnamed: 0 Speech_id  \
# 49358       49359      3355
#
#                                                     text party    term   comp  \
# 49358  And I'm going to take a page from Harry Truman...   rep  1996.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 49358                 False      13       3355_13
#                                                    text  pred_class  \
# 2137  And I'm going to take a page from Harry Truman...           0
#
#      speech_par_id speech_par_id_old
# 2137       3355_13           3355_13
#     Unnamed: 0 Speech_id                                               text  \
# 78          79       906  Well, I agree with him. They should. But appar...
#
#    party    term   comp populist_old_keywords  par_id speech_par_id
# 78   dem  1952.0  False                 False       7         906_7
#                                                    text  pred_class  \
# 2170  Well, I agree with him. They should. But appar...           0
#
#      speech_par_id speech_par_id_old
# 2170         906_7             906_7
#     Unnamed: 0 Speech_id                                               text  \
# 80          81       906  There is the federal-state-local health progra...
#
#    party    term  comp populist_old_keywords  par_id speech_par_id
# 80   dem  1952.0  True                 False       9         906_9
#                                                    text  pred_class  \
# 2171  There is the federal-state-local health progra...           0
#
#      speech_par_id speech_par_id_old
# 2171         906_9           3103_21
#        Unnamed: 0 Speech_id  \
# 44908       44909       921
#
#                                                     text party    term  comp  \
# 44908  Well, I don't deserve any of the things you ar...   dem  1952.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 44908                 False       2         921_2
#                                                    text  pred_class  \
# 2181  Well, I don't deserve any of the things you ar...           0
#
#      speech_par_id speech_par_id_old
# 2181         921_2             921_2
#        Unnamed: 0 Speech_id  \
# 25263       25264       944
#
#                                                     text party    term  comp  \
# 25263  3. By retraining men who are replaced by machi...   dem  1952.0  True
#
#       populist_old_keywords  par_id speech_par_id
# 25263                 False      18        944_18
#                                                    text  pred_class  \
# 2190  3. By retraining men who are replaced by machi...           0
#
#      speech_par_id speech_par_id_old
# 2190        944_18            944_18
#        Unnamed: 0 Speech_id  \
# 18986       18987       977
#
#                                                     text party    term   comp  \
# 18986  My opponent said the other day that he is one ...   dem  1952.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 18986                 False      11        977_11
#                                                    text  pred_class  \
# 2212  My opponent said the other day that he is one ...           0
#
#      speech_par_id speech_par_id_old
# 2212        977_11            977_11
#        Unnamed: 0 Speech_id  \
# 31158       31159       991
#
#                                                     text party    term   comp  \
# 31158  The flood control program in the Trinity River...   dem  1952.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 31158                 False      24        991_24
#                                                    text  pred_class  \
# 2220  The flood control program in the Trinity River...           0
#
#      speech_par_id                  speech_par_id_old
# 2220        991_24  2016-08-05-green-bay-wisconsin_34

# %%
not_aligned = not_aligned.merge(dat[["speech_par_id", "text"]], how = "left", on = "speech_par_id")
#not_aligned_df = pd.DataFrame(not_aligned)
not_aligned
# Out:
#     Unnamed: 0 Speech_id                                             text_x  \
# 0        36013      1092  I don't know how thick your hide is.  But it's...
# 1        25705      1108  Mr. Chairman, ladies and gentlemen:  If I cann...
# 2         7064      1170  Now, that is the kind of recommendation that i...
# 3        42243      1183  Ladies and gentlemen: there is not much relati...
# 4        40295      1234  Governor Barrett, I see there are some people ...
# ..         ...       ...                                                ...
# 160         81       906  There is the federal-state-local health progra...
# 161      44909       921  Well, I don't deserve any of the things you ar...
# 162      25264       944  3. By retraining men who are replaced by machi...
# 163      18987       977  My opponent said the other day that he is one ...
# 164      31159       991  The flood control program in the Trinity River...
#
#     party    term   comp populist_old_keywords par_id speech_par_id  \
# 0     rep  1952.0  False                 False     14       1092_14
# 1     rep  1952.0   True                 False      0        1108_0
# 2     rep  1952.0  False                 False      2        1170_2
# 3     rep  1952.0  False                 False      0        1183_0
# 4     rep  1952.0   True                 False      0        1234_0
# ..    ...     ...    ...                   ...    ...           ...
# 160   dem  1952.0   True                 False      9         906_9
# 161   dem  1952.0   True                 False      2         921_2
# 162   dem  1952.0   True                 False     18        944_18
# 163   dem  1952.0  False                 False     11        977_11
# 164   dem  1952.0  False                 False     24        991_24
#
#                                                 text_y
# 0    I don't know how thick your hide is.  But it's...
# 1    Mr. Chairman, ladies and gentlemen:  If I cann...
# 2    Now, that is the kind of recommendation that i...
# 3    Ladies and gentlemen: there is not much relati...
# 4    Governor Barrett, I see there are some people ...
# ..                                                 ...
# 160  There is the federal-state-local health progra...
# 161  Well, I don't deserve any of the things you ar...
# 162  3. By retraining men who are replaced by machi...
# 163  My opponent said the other day that he is one ...
# 164  The flood control program in the Trinity River...
#
# [165 rows x 10 columns]

# %%
not_aligned[not_aligned['text_x'] == not_aligned['text_y']]
# Out:
#     Unnamed: 0 Speech_id                                             text_x  \
# 0        36013      1092  I don't know how thick your hide is.  But it's...
# 1        25705      1108  Mr. Chairman, ladies and gentlemen:  If I cann...
# 2         7064      1170  Now, that is the kind of recommendation that i...
# 3        42243      1183  Ladies and gentlemen: there is not much relati...
# 4        40295      1234  Governor Barrett, I see there are some people ...
# ..         ...       ...                                                ...
# 160         81       906  There is the federal-state-local health progra...
# 161      44909       921  Well, I don't deserve any of the things you ar...
# 162      25264       944  3. By retraining men who are replaced by machi...
# 163      18987       977  My opponent said the other day that he is one ...
# 164      31159       991  The flood control program in the Trinity River...
#
#     party    term   comp populist_old_keywords par_id speech_par_id  \
# 0     rep  1952.0  False                 False     14       1092_14
# 1     rep  1952.0   True                 False      0        1108_0
# 2     rep  1952.0  False                 False      2        1170_2
# 3     rep  1952.0  False                 False      0        1183_0
# 4     rep  1952.0   True                 False      0        1234_0
# ..    ...     ...    ...                   ...    ...           ...
# 160   dem  1952.0   True                 False      9         906_9
# 161   dem  1952.0   True                 False      2         921_2
# 162   dem  1952.0   True                 False     18        944_18
# 163   dem  1952.0  False                 False     11        977_11
# 164   dem  1952.0  False                 False     24        991_24
#
#                                                 text_y
# 0    I don't know how thick your hide is.  But it's...
# 1    Mr. Chairman, ladies and gentlemen:  If I cann...
# 2    Now, that is the kind of recommendation that i...
# 3    Ladies and gentlemen: there is not much relati...
# 4    Governor Barrett, I see there are some people ...
# ..                                                 ...
# 160  There is the federal-state-local health progra...
# 161  Well, I don't deserve any of the things you ar...
# 162  3. By retraining men who are replaced by machi...
# 163  My opponent said the other day that he is one ...
# 164  The flood control program in the Trinity River...
#
# [165 rows x 10 columns]

# %%
not_aligned = []
for filename in os.listdir("/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/"):
    ## load the test set 
    file = "/Users/yuchenluo/Desktop/Measure_RadicalDiscourse/codes/Prediction_of_test_inclusion/" + "/" + filename
    test = pd.read_csv(file)
    for id in test['speech_par_id']:
        if id in dat['speech_par_id']:
            if dat[dat['speech_par_id']== id]['text'].values[0] != test[test["speech_par_id"] == id]['text'].values[0]:
                print(dat[dat['speech_par_id']== id])
                print(test[test["speech_par_id"] == id])
                not_aligned.append(dat[dat['speech_par_id']== id])

# %%
dat.loc[dat['speech_par_id']== annotated["speech_par_id"][1],'text'].values[0]
# Out:
# 'We are opposing Communism abroad, where its relentless pressure seeks further to narrow the area of freedom. We are opposing it at home where its agents and converts seek to undermine our society and corrupt our government. As I have repeatedly said, the federal government must use all its resources to expose and identify Communistic activity, to keep Communists out of places of responsibility in our society, and to protect our institutions from Communist espionage, sabotage and subversion. '

# %%
missing_ids = []
for id in annotated['speech_par_id']:
    if id not in dat['speech_par_id'].tolist():
        missing_ids = missing_ids + [id]
        
len(missing_ids)
# Out:
# 1

# %%
dat = pd.read_csv("20220131_all_paragraphs_2020_added_missings_added.csv")

# %%
dat[dat['speech_par_id']== "1009_30"]['text'].values[0] != annotated[annotated["speech_par_id"] == "1009_30"]['text'].values[0]
# Out:
# False

# %%
dat[dat["speech_par_id"] == "1009_30"]
# Out:
#        Unnamed: 0 Speech_id  \
# 43817       43818      1009
#
#                                                     text party    term   comp  \
# 43817  We are opposing Communism abroad, where its re...   dem  1952.0  False
#
#       populist_old_keywords  par_id speech_par_id
# 43817                 False      30       1009_30

# %%
annotated['speech_par_id'][1] in dat['speech_par_id'].tolist()
# Out:
# True

# %%
annotated['speech_par_id'][1]
# Out:
# '1009_30'
